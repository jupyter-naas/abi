# %% [markdown]
# <img width="8%" alt="LinkedIn.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/LinkedIn.png" style="border-radius: 15%">

# %% [markdown]
# # LinkedIn - Send Fine-tuned dataset from posts to Google Sheets

# %% [markdown]
# **Tags:** #linkedin #profile #post #stats #naas_drivers #content #automation #gsheet

# %% [markdown]
# **Author:** [Maxime Jublou](https://www.linkedin.com/in/maximejublou/)

# %% [markdown]
# **Last update:** 2023-11-14 (Created: 2023-11-14)

# %% [markdown]
# **Description:** This notebook fetches your profile's post statistics from LinkedIn, transform them into a dataset to be fine-tuned with an LLM model.

# %% [markdown]
# <div class="alert alert-info" role="info" style="margin: 10px">
# <b>Disclaimer:</b><br>
# This code is in no way affiliated with, authorized, maintained, sponsored or endorsed by Linkedin or any of its affiliates or subsidiaries. It uses an independent and unofficial API. Use at your own risk.
#
# This project violates Linkedin's User Agreement Section 8.2, and because of this, Linkedin may (and will) temporarily or permanently ban your account. We are not responsible for your account being banned.
# <br>
# </div>

# %% [markdown]
# ### Import libraries

# %%
from naas_drivers import linkedin, gsheet
import naas
import pickle
import openai
import json
from tqdm import tqdm
import pandas as pd
import time
from IPython import display
import naas_data_product

# %% [markdown]
# ### Setup variables
# **Mandatory**
#
# [Learn how to get your cookies on LinkedIn](https://www.notion.so/LinkedIn-driver-Get-your-cookies-d20a8e7e508e42af8a5b52e33f3dba75)
# - `li_at`: Cookie used to authenticate Members and API clients.
# - `JSESSIONID`: Cookie used for Cross Site Request Forgery (CSRF) protection and URL signature validation.
# - `linkedin_url`: This variable represents the LinkedIn profile URL.
# - `openai.api_key`: Connect to OpenAI with the API key.
#
# **Optional**
# - `limit`: number of posts to be retrieved.

# %%
# Mandatory
li_at = naas.secret.get("LINKEDIN_LI_AT") or "YOUR_LINKEDIN_LI_AT" #example: AQFAzQN_PLPR4wAAAXc-FCKmgiMit5FLdY1af3-2
JSESSIONID = naas.secret.get("LINKEDIN_JSESSIONID") or "YOUR_LINKEDIN_JSESSIONID" #example: ajax:8379907400220387585
linkedin_url = "https://www.linkedin.com/in/jeremyravenel/"  # EXAMPLE "https://www.linkedin.com/in/XXXXXX/"
openai.api_key = naas.secret.get("OPENAI_API_KEY")
spreadsheet_url = "https://docs.google.com/spreadsheets/d/1wediMdHcq5WDqLMZ7ryNrcPxCmlX8BX4ZEl3JNWT8wg/edit#gid=0"
sheet_name = "Jeremy"
avatar_owner = "Jeremy Ravenel"

# Optional
output_dir = os.path.join(naas_data_product.OUTPUTS_PATH, "ai-characters", avatar_owner.lower().replace(" ", "_"))
os.makedirs(output_dir, exist_ok=True)
limit = 50

# %% [markdown]
# ## Model

# %% [markdown]
# ### Pickel functions

# %% [markdown]
# #### Pickle dump

# %%
def pdump(
    output_dir,
    object_to_dump,
    file_to_dump_to
):
    file_path = os.path.join(output_dir, f'{file_to_dump_to}.pickle')
    with open(file_path, 'wb') as file:
        pickle.dump(object_to_dump, file)

# %% [markdown]
# #### Pickle load

# %%
def pload(
    output_dir,
    file_to_load_from
):
# 45  2023-09-25 14:34:27+0200   Jérémy Ravenel
# 46  2023-09-25 13:30:08+0200   Jérémy Ravenel
# 47  2023-09-21 19:40:35+0200  Eric Vyacheslav
# 48  2023-09-15 13:41:35+0200   Jérémy Ravenel
# 49  2023-09-13 22:16:15+0200   Jérémy Ravenel
#
#                                            AUTHOR_URL     SUBDESCRIPTION  \
# 0   https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...           17h •
# 1   https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...            1d •
# 2   https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...            2d •
# 3   https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...            3d •
# 4   https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...            4d •
# 5   https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...            5d •
# 6   https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...            6d •
# 7   https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...            6d •
# 8   https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...            1w •
# 9   https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...            1w •
# 10  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...            1w •
# 11  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...            1w •
# 12  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...            1w •
# 13  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...            1w •
# 14  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...            1w •
# 15  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...            2w •
# 16  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...            2w •
# 17  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...            2w •
# 18  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...            2w •
# 19  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...            2w •
# 20  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...            3w •
# 21  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...            3w •
# 22  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...            3w •
# 23  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...            3w •
# 24  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...            3w •
# 25  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...            3w •
# 26  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...           1mo •
# 27  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...           1mo •
# 28  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...           1mo •
# 29  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...  1mo • Edited •
# 30  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...           1mo •
# 31  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...           1mo •
# 32  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...           1mo •
# 33  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...           1mo •
# 34  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...           1mo •
# 35  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...  1mo • Edited •
# 36  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...           1mo •
# 37  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...           1mo •
# 38  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...           1mo •
# 39  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...           1mo •
# 40  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...           1mo •
# 41  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...           1mo •
# 42  https://www.linkedin.com/in/ACoAAA25dK0B8Mc6cE...           1mo •
# 43  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...           1mo •
# 44  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...           1mo •
# 45  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...           1mo •
# 46  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...           1mo •
# 47  https://www.linkedin.com/in/ACoAACgVdBIBnVU5t_...           2mo •
# 48  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...           2mo •
# 49  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...           2mo •
#
#                                                 TITLE  \
# 0   What if GPTs are a distraction on what OpenAI ...
# 1   AI Agents vs Assistants vs Avatars. What's the...
# 2   Today, I experienced something quite remarkabl...
# 3   Let's fight those who want to capture the AI m...
# 4   📩 I have started building my first GPT to clea...
# 5   Don't put all your eggs in the same basket. Th...
# 6   Since we launched our open source program, mor...
# 7   🤪 Tired of the "50 tricks on how to use chatGP...
# 8   What was the big missing ingredient of yesterd...
# 9   Prompting is plumbing in AI. It just became ev...
# 10  If I started programming now, I would start by...
# 11  Knowledge Graphs have gained significant atten...
# 12  🌎 I'm testing different methods to build an AI...
# 13  😎 Enabling any individual or organization to o...
# 14  Hacktoberfest has officially come to a close, ...
# 15  "Focusing on the future existential risks of A...
# 16  AI SaaS meeting summarizers will produce inacc...
# 17  George Orwell's "1984” is a masterpiece. I bel...
# 18  We need to have an open conversation about the...
# 19  "Generative AI is something that should help m...
# 20  In AI Wonderland, the discussions around fine-...
# 21  LLMs did not change anything since I posted th...
# 22  AI's capabilities extend far beyond writing bl...
# 23  ☝️ Why?...is the first question you need to as...
# 24  ⚡️The primary goal of frameworks is to find mi...
# 25  I just finished the course “Decision Intellige...
# 26  🎙️ It's a true privilege to be able to discuss...
# 27  "Fun Fact": Nobody created artificial intellig...
# 28  I’m having so much fun talking to famous chara...
# 29  Data is a reflection of the world we live in: ...
# 30  Thanks Yann LeCun for this strong call to acti...
# 31  I am honored to team up with the best network ...
# 32  While generative AI takes over the world, anal...
# 33  I'm excited to announce our participation in H...
# 34  OK, AI can summarize text. But by doing that, ...
# 35  💡💚 CEOs love disruptors because they are obses...
# 36               Gold nugget from Pau Labarta Bajo  👇
# 37  Developing an AI system looks like portfolio m...
# 38  Let's not overthink AI too much, it's all abou...
# 39  An opinionated data model is the most critical...
# 40             AI does not prevent us from thinking.
# 41  Maybe there’s a hype cycle, but it’s not hype ...
# 42          𝗧𝗼𝗱𝗮𝘆 𝗶𝘀 𝗮𝗻 𝗲𝘅𝗰𝗶𝘁𝗶𝗻𝗴 𝗱𝗮𝘆 𝗳𝗼𝗿 𝗔𝗜 𝗮𝘁 𝗦𝗔𝗣! 🥳
# 43  The "Data & AI Product Development" discipline...
# 44  Even if I love open source, I’m still using op...
# 45  The partnership between Amazon + Anthropic  wi...
# 46  Only 5% of people believe AI will be extremely...
# 47  Did Steve Jobs anticipate Large Language Model...
# 48  I'll talk to the Decoding Data Science Communi...
# 49  Do you know the difference between an AI Base ...
#
#                                                  TEXT  CHARACTER_COUNT  \
# 0   What if GPTs are a distraction on what OpenAI ...              192
# 1   AI Agents vs Assistants vs Avatars. What's the...             1044
# 2   Today, I experienced something quite remarkabl...             1129
# 3   Let's fight those who want to capture the AI m...              177
# 4   📩 I have started building my first GPT to clea...             1948
# 5   Don't put all your eggs in the same basket. Th...             1790
# 6   Since we launched our open source program, mor...              595
# 7   🤪 Tired of the "50 tricks on how to use chatGP...             2128
# 8   What was the big missing ingredient of yesterd...              936
# 9   Prompting is plumbing in AI. It just became ev...             2102
# 10  If I started programming now, I would start by...             1170
# 11  Knowledge Graphs have gained significant atten...             1256
# 12  🌎 I'm testing different methods to build an AI...             1892
# 13  😎 Enabling any individual or organization to o...              870
# 14  Hacktoberfest has officially come to a close, ...             1007
# 15  "Focusing on the future existential risks of A...              303
# 16  AI SaaS meeting summarizers will produce inacc...             1471
# 17  George Orwell's "1984” is a masterpiece. I bel...              438
# 18  We need to have an open conversation about the...             1869
# 19  "Generative AI is something that should help m...              692
# 20  In AI Wonderland, the discussions around fine-...             1992
# 21  LLMs did not change anything since I posted th...              857
# 22  AI's capabilities extend far beyond writing bl...              813
# 23  ☝️ Why?...is the first question you need to as...             1475
# 24  ⚡️The primary goal of frameworks is to find mi...             2277
# 25  I just finished the course “Decision Intellige...              355
# 26  🎙️ It's a true privilege to be able to discuss...              779
# 27  "Fun Fact": Nobody created artificial intellig...              444
# 28  I’m having so much fun talking to famous chara...             1056
# 29  Data is a reflection of the world we live in: ...               53
# 30  Thanks Yann LeCun for this strong call to acti...              167
# 31  I am honored to team up with the best network ...              570
# 32  While generative AI takes over the world, anal...              575
# 33  I'm excited to announce our participation in H...             1189
# 34  OK, AI can summarize text. But by doing that, ...             1224
# 35  💡💚 CEOs love disruptors because they are obses...             1095
# 36  Gold nugget from Pau Labarta Bajo  👇\nI also n...              288
# 37  Developing an AI system looks like portfolio m...             1678
# 38  Let's not overthink AI too much, it's all abou...              478
# 39  An opinionated data model is the most critical...             1426
# 40  AI does not prevent us from thinking. \n\nIt h...              470
# 41  Maybe there’s a hype cycle, but it’s not hype ...              110
# 42  𝗧𝗼𝗱𝗮𝘆 𝗶𝘀 𝗮𝗻 𝗲𝘅𝗰𝗶𝘁𝗶𝗻𝗴 𝗱𝗮𝘆 𝗳𝗼𝗿 𝗔𝗜 𝗮𝘁 𝗦𝗔𝗣! 🥳\n\nI...              839
# 43  The "Data & AI Product Development" discipline...              274
# 44  Even if I love open source, I’m still using op...              101
# 45  The partnership between Amazon + Anthropic  wi...              199
# 46  Only 5% of people believe AI will be extremely...             1227
# 47  Did Steve Jobs anticipate Large Language Model...              229
# 48  I'll talk to the Decoding Data Science Communi...             1000
# 49  Do you know the difference between an AI Base ...             1784
#
#                                                  TAGS  ...  POLL_ID  \
# 0                                                None  ...     None
# 1                                                None  ...     None
# 2                                                None  ...     None
# 3                                                None  ...     None
# 4                                                None  ...     None
# 5                                                None  ...     None
# 6                                                None  ...     None
# 7                                                None  ...     None
# 8                                                None  ...     None
# 9                                                None  ...     None
# 10                                               None  ...     None
# 11                                               None  ...     None
# 12                                               None  ...     None
# 13                                               None  ...     None
# 14        #hacktoberfest2023 #opensource #datascience  ...     None
# 15                                               None  ...     None
# 16                                               None  ...     None
# 17                                               None  ...     None
# 18  #AI #MachineLearning #DataScience #AIavatars #...  ...     None
# 19                                               None  ...     None
# 20                                               None  ...     None
# 21                                               None  ...     None
# 22                                               None  ...     None
# 23                                               None  ...     None
# 24                                               None  ...     None
# 25          #datadrivendecisionmaking #decisionmaking  ...     None
# 26             #dataentrepreneurs #ai #transformation  ...     None
# 27                                     #ai #education  ...     None
# 28                        #characters #ai #networking  ...     None
# 29                                               None  ...     None
# 30                                               None  ...     None
# 31                                               None  ...     None
# 32                                               None  ...     None
# 33  #notebooks #genAI #data #automation #analytics...  ...     None
# 34                                               None  ...     None
# 35  #DataScience #AI #Strategy #Disruption #Innova...  ...     None
# 36                    #dataproducts #ai #ml #pipeline  ...     None
# 37                                               None  ...     None
# 38                                          #leandata  ...     None
# 39  #DataModel #AI #ProductDevelopment #NoCode #Da...  ...     None
# 40                                               None  ...     None
# 41                                               None  ...     None
# 42  #ArtificialIntelligence #GenerativeAI #SAP #Co...  ...     None
# 43                                               None  ...     None
# 44                                               None  ...     None
# 45                                               None  ...     None
# 46  #artificialIntelligence #earlyadopters #datapr...  ...     None
# 47                                               None  ...     None
# 48         #community #meetup #data #ai #dataproducts  ...     None
# 49                             #ai #models #knowledge  ...     None
#
#    POLL_QUESTION  POLL_RESULTS  \
# 0           None          None
# 1           None          None
# 2           None          None
# 3           None          None
# 4           None          None
# 5           None          None
# 6           None          None
# 7           None          None
# 8           None          None
# 9           None          None
# 10          None          None
# 11          None          None
# 12          None          None
# 13          None          None
# 14          None          None
# 15          None          None
# 16          None          None
# 17          None          None
# 18          None          None
# 19          None          None
# 20          None          None
# 21          None          None
# 22          None          None
# 23          None          None
# 24          None          None
# 25          None          None
# 26          None          None
# 27          None          None
# 28          None          None
# 29          None          None
# 30          None          None
# 31          None          None
# 32          None          None
# 33          None          None
# 34          None          None
# 35          None          None
# 36          None          None
# 37          None          None
# 38          None          None
# 39          None          None
# 40          None          None
# 41          None          None
# 42          None          None
# 43          None          None
# 44          None          None
# 45          None          None
# 46          None          None
# 47          None          None
# 48          None          None
# 49          None          None
#
#                                              POST_URL  VIEWS COMMENTS LIKES  \
# 0   https://www.linkedin.com/feed/update/urn:li:ac...      0        9    15
#
#    SHARES ENGAGEMENT_SCORE         DATE_EXTRACT
# 0       0                0  2023-11-15 16:35:31
# 1       0                0  2023-11-15 16:35:31
# 2       0                0  2023-11-15 16:35:32
# 3       0                0  2023-11-15 16:35:33
# 4       3                0  2023-11-15 16:35:34
# 5       2                0  2023-11-15 16:35:35
# 6       0                0  2023-11-15 16:35:36
# 7       1                0  2023-11-15 16:35:37
# 8       2                0  2023-11-15 16:35:37
# 9       0                0  2023-11-15 16:35:38
# 10     25                0  2023-11-15 16:35:39
# 11      5                0  2023-11-15 16:35:40
# 12      0                0  2023-11-15 16:35:41
# 13      1                0  2023-11-15 16:35:42
# 14      0                0  2023-11-15 16:35:43
# 15      0                0  2023-11-15 16:35:44
# 16      0                0  2023-11-15 16:35:45
# 17      0                0  2023-11-15 16:35:45
# 18      0                0  2023-11-15 16:35:46
# 19      1                0  2023-11-15 16:35:47
# 20      3                0  2023-11-15 16:35:48
# 21      0                0  2023-11-15 16:35:49
# 22      0                0  2023-11-15 16:35:49
# 23      1                0  2023-11-15 16:35:50
# 24      2                0  2023-11-15 16:35:51
# 25      0                0  2023-11-15 16:35:53
# 26      0                0  2023-11-15 16:35:53
# 27      2                0  2023-11-15 16:35:54
# 28      0                0  2023-11-15 16:35:55
# 29      0                0  2023-11-15 16:35:55
# 30      0                0  2023-11-15 16:35:56
# 31      0                0  2023-11-15 16:35:57
# 32      4                0  2023-11-15 16:35:58
# 33      1                0  2023-11-15 16:35:58
# 34      0                0  2023-11-15 16:36:00
# 35      0                0  2023-11-15 16:36:00
# 36      0                0  2023-11-15 16:36:02
# 37      1                0  2023-11-15 16:36:02
# 38      1                0  2023-11-15 16:36:04
# 39      1                0  2023-11-15 16:36:04
# 40      0                0  2023-11-15 16:36:05
# 41      0                0  2023-11-15 16:36:06
# 42      0                0  2023-11-15 16:36:07
# 43      0                0  2023-11-15 16:36:08
# 44      0                0  2023-11-15 16:36:09
# 45      0                0  2023-11-15 16:36:09
# 46      0                0  2023-11-15 16:36:10
# 47      0                0  2023-11-15 16:36:11
# 48      0                0  2023-11-15 16:36:12
# 49      0                0  2023-11-15 16:36:13
#
# [50 rows x 32 columns]

# %% [markdown]
# ### Data set preparation

# %%
def get_full_name(sentence):
    response = openai.ChatCompletion.create(
        model="gpt-4",
        temperature=0,
        messages=[
            {
                "role": "system",
                "content": """
                    The user will pass you a sentence with the name of the person. You must output the full name of the person. NOTHING ELSE.
                    
                    ```example_user_message
                    "Hello my name is John Doe 🚀"
                    ```
                    
                    ```example_answer
                    John Doe
                    ```
                    """
            
            },
            {
                "role": "user",
                "content": sentence
            }
        ]
    )
    
    return response['choices'][0]['message']['content']

full_name = pload(output_dir, 'full_name')

if full_name is None:
    full_name = get_full_name(posts.iloc[0].AUTHOR_NAME)
    pdump(output_dir, full_name, 'full_name')

full_name
# Out:
# 'Jérémy Ravenel'

# %% [markdown]
# ### Generate questions that should lead to post generation

# %%
def generate_question_from_text(text, prompt, text_model):
    response = openai.ChatCompletion.create(
        model=text_model,
        temperature=0,
        messages=[
            {
                "role": "system",
                "content": prompt
            },
            {
                "role": "user",
                "content": text
            }
        ]
    )
    
    return response['choices'][0]['message']['content']

    
question_prompt = f"""
    You are a highly skilled AI trained in language comprehension and creation of prompt that could lead to the text provided by the user.
    I would like you to read the following text and create the prompt that would lead to the LLM generate that specific text.
    The texts being provided are post from LinkedIn.
    Please avoid unnecessary details or tangential points.
    
    ```instructions
    WRITE IN THE LANGUAGE THE TEXT IS IN
    ```
"""

texts = [p.TEXT for _, p in posts.iterrows()]
questions = pload(output_dir, 'questions')

if questions is None:
    questions = [generate_question_from_text(text, question_prompt, "gpt-4") for text in tqdm(texts)]
    pdump(output_dir, questions, 'questions')

questions
# Out:
# 100%|██████████| 50/50 [06:55<00:00,  8.30s/it]
# ["As an AI enthusiast, share your thoughts on OpenAI's mission to create AGI and how GPTs fit into this vision. Discuss if you think GPTs might be a distraction from what OpenAI is actually planning next and if there seems to be a missing piece in the puzzle.",
#  'As an AI expert, explain the differences between AI Agents, AI Assistants, and AI Avatars, providing definitions and examples for each. Also, discuss their roles in the AI landscape and ask for feedback on your explanation.',
#  'Write a LinkedIn post about your recent experience using the voice feature of the ChatGPT app for a 45-minute session. Discuss how the AI assistant helped you structure and articulate your thoughts for an AI Avatar project, emphasizing the step-by-step approach and the importance of focused dialogue. Share your insights on how AI can be a valuable tool not just for generating ideas but for refining and articulating them, and how the voice feature enhances accessibility.',
#  'As an AI enthusiast, express your concerns about the monopolization of the AI market and your desire to build open alternatives. Share your fears about the future where a pseudo "open AI" could potentially control everyone\'s second brain.',
#  'Write a LinkedIn post about your experience building your first GPT to clean your mailbox and focus on emails that need a follow-up. Discuss the process you went through, the challenges you faced, the reasons for the initial inaccuracies, and the importance of human involvement in refining the model.',
#  'As an AI enthusiast who recently experienced a major outage of ChatGPT while trying to build your first Assistant in the OpenAI playground, share your thoughts on the importance of owning your AI system. Discuss the risks of dependency on a single provider for AI needs, the benefits of owning your AI system, and the limitations of relying solely on external "no-code" platforms. Ask your LinkedIn connections about their experiences and insights on owning their AI systems and any disruptions they\'ve faced due to reliance on third-party platforms.',
#  "As the head of an open source program that recently launched, write a LinkedIn post inviting interested individuals to join a call to learn more about the program's progress and future plans. Mention the challenges faced in managing 1:1 interactions and assure that everyone is welcome to join, regardless of whether they are already part of the program or not.",
#  'Write a LinkedIn post explaining the C.I.D.I. framework for creating effective prompts for language models, including what each letter stands for and how to use them. Also, mention the importance of each element in the process and encourage readers to try this framework. Finally, acknowledge the creator of the framework, Gianluca Mauro.',
#  'Create a LinkedIn post discussing the importance of data quality in AI systems, using the recent OpenAI Dev Day as an example. Highlight the need for companies to refine their data collection and curation processes and suggest ways to improve data quality.',
#  'Write a LinkedIn post discussing the importance and potential applications of prompting in AI, as highlighted during the OpenAI dev day. Discuss how it can be used for creative content generation, customizable user experiences, domain-specific expertise, language learning and translation, and the development of virtual assistants and chatbots. Conclude by comparing the role of prompting in AI to plumbing, keeping things flowing smoothly.',
#  "Create a LinkedIn post discussing the importance of learning to prompt in programming, drawing parallels between functions in programming and prompting in LLMs. Mention how this understanding can be beneficial for beginners in programming. Also, recommend a post by François Chollet, the Google engineer behind Keras, for a deeper understanding of the concept. Conclude the post by expressing your appreciation for Chollet's approach.",
#  'Write a LinkedIn post about the benefits of using Pyvis, a Python library, for visualizing Knowledge Graphs. Discuss how it helps users understand complex relationships and connections within the data, and mention the customization options it offers. Also, share a link to a template you published on Naas awesome-notebooks template catalog demonstrating how to use Pyvis.',
#  "You are a tech enthusiast who is currently experimenting with building an AI system that incorporates the worldview of a CEO. You believe that such a system can assist not only CEOs but also their collaborators in making more informed decisions. You are exploring the benefits of this system, the challenges in replicating a CEO's worldview, and the potential of this system to democratize access to strategic insights. You are also trying to find a balance between prompting, finetuning, and embedding in the development of this AI system. Share your thoughts and invite others to discuss their experiences or thoughts on this topic.",
#  'As an AI expert, share your thoughts on the importance of AI ownership and governance. Discuss the potential dangers of a few powerful entities controlling AI systems and the need for openness and transparency in AI governance. Mention your support for the Joint Statement on AI Safety and Openness by Mozilla and explain why you signed it. Conclude by emphasizing that openness is the solution, not the problem, for AI safety and security.',
#  "As a company that just concluded its participation in Hacktoberfest, write a LinkedIn post summarizing your achievements during the event. Mention the number of contributors who joined, the number of PRs closed, the creation of various templates for popular platforms, and improvements made to existing templates. Give a shoutout to the most active contributors and invite the community to a call to learn more about these templates and the current state of development of your product. Don't forget to provide a link for people to join the call and express gratitude for the support received. Use relevant hashtags like #hacktoberfest2023, #opensource, and #datascience.",
#  'As an AI expert, share your thoughts on the current impacts of AI and the need for proper regulation. Also, mention a recent talk by Sasha Luccioni, PhD, that you found particularly insightful and recommend it to data & AI professionals.',
#  'You are an expert in AI and SaaS meeting summarizers. Write a LinkedIn post discussing the common issues with AI SaaS meeting summarizers, such as their lack of context and difficulty with complex or nuanced information. Explain the common sources of these issues and suggest a solution, which involves using a custom script to provide more context. Offer to help those who are struggling with these issues and hint at a future post discussing workflow integration.',
#  'Write a LinkedIn post discussing your thoughts on George Orwell\'s "1984", its relevance in today\'s world, especially in relation to technology, ethics, and human rights. Also, mention that you are currently listening to it as an audiobook and recommend it to those working in the data & AI space.',
#  'As an AI expert working at naas.ai, you are currently involved in a project to create a high-quality dataset for building AI avatars. You have developed a 12-step process for this task and want to share it on LinkedIn to invite feedback and collaboration from your network. You also want to emphasize the importance of curating data for AI systems and data products. Write a post detailing your process and inviting comments and suggestions.',
#  'As an AI, write a LinkedIn post expressing the frustration of a CEO named Mr ABC from XYZ company about the lack of practical business use cases for Generative AI. Also, emphasize the importance of data mining, mastering versioning tools like GitHub, and efficient human communication in AI implementation. Conclude the post by stating that while paradigms may change, the fundamentals remain the same.',
#  'As an AI expert working at naas.ai, you have been exploring the concept of the "AI Trinity" - fine-tuning models, prompt engineering, and document retrieval augmentation (RAG) techniques. You believe that these three aspects are crucial in creating an AI system that can impersonate a brand voice, follow specific prompts, and retrieve relevant information. You are eager to share your insights and experiences with your LinkedIn network and invite them to discuss their own experiences with these aspects of generative AI.',
#  'As an AI expert, share your thoughts on the importance of data quality for the successful adoption of technology, particularly large language models. Discuss your experience with automated data analysis tools, such as OpenAI, and their limitations when dealing with "dirty" data. Emphasize the need for clean datasets and the principle of "garbage in, garbage out" in AI systems.',
#  'Write a LinkedIn post discussing the potential of AI in various fields, particularly in the medical realm, and emphasizing its impact on our lives beyond just business productivity. Use a recent New York Times article about an AI tool developed for diagnosing brain tumors as an example.',
#  'Write a LinkedIn post discussing the importance of asking "why" in personal development and growth, drawing inspiration from motivational speaker Jim Rohn. Discuss how this question can fuel determination and success, and encourage readers to reflect on their own "whys". Also, introduce the questions "why not you?" and "why not now?" to further motivate readers to pursue their dreams and make a positive impact.',
#  "As a software developer and AI product manager, you have recently been considering the importance of frameworks in software development and how they can help find mistakes faster and more efficiently. You believe that frameworks promote consistency, standardization, and provide pre-built components that speed up work. You also think that they help catch mistakes early in the development process. You have been working with Naas, a framework for creating data & AI products, and are considering putting together a course on it. Share your thoughts on LinkedIn and ask your connections if they would be interested in such a course. Also, provide a link to the current state of the framework you're using.",
#  "As an AI, share your recent experience of completing the course “Decision Intelligence” on LinkedIn Learning. Express your recommendation for anyone interested in making data meaningful and using it for decision-making. Mention the value you found in the course and the fact that it's available for free. Also, include the time it takes to complete the course and use relevant hashtags.",
#  'Write a LinkedIn post where you express your excitement about discussing the transformative potential of LLMs and Python with data entrepreneurs. Mention how this combination can revolutionize work dynamics and allow for tackling complex issues. Encourage others to master the craft of data & AI product building to break free from monotonous routines. Invite people to join a meeting on Friday using a link shared by Shawhin Talebi. Conclude by thanking for the support and use hashtags related to data entrepreneurs, AI, and transformation.',
#  'Write a LinkedIn post discussing the discovery of artificial intelligence, comparing it to the discovery of electricity. Mention Geoffrey Hinton, often referred to as the "Godfather of AI," and his accidental discovery of AI while studying the human brain at the University of Edinburgh in the 1970s. Include a link to a related video and use hashtags related to AI and education.',
#  'You are currently testing new notebook templates on naas.ai that create plugins, allowing you to interact with famous historical figures. You are learning more about these individuals and their lives, and one interaction that particularly stood out was with JD Rockefeller. You are also working on automating the process of logging social and product interactions into your CRM with your colleagues Maxime and Florent. Share your experience and ask your LinkedIn connections about their current issues or challenges, and how they manage and record their interactions.',
#  'Write a short statement about your perspective on data and its relation to the world we live in.',
#  'Write a LinkedIn post expressing your gratitude towards Yann LeCun for his call to action and emphasizing the need for more practical and nuanced wisdom from professionals who have been instrumental in building their respective disciplines.',
#  'As a professional collaborating with a leading network, write a LinkedIn post expressing your excitement about your partnership. Your goal is to bridge the gap between businesses and the open source community, fostering innovation and collaboration within organizations that use open source in their tech supply chain. You also aim to help individuals earn from their contributions to open source. Mention your commitment to empowering people to thrive in the open source world and creating a global impact. Hint at more exciting news to come and encourage your followers to spread the love for open source.',
#  'Write a LinkedIn post discussing the challenges faced by analysts due to the rise of generative AI, the inefficiency of data teams, and the lack of a proper framework. Also, question if integrating Python in Excel could potentially solve these issues.',
#  "As a representative of Naas.ai, announce your company's participation in Hacktoberfest '23. Share your mission to create the largest catalog of curated Jupyter Notebook templates and explain the importance of the IMO framework. Mention your template catalog, awesome-notebooks, and its current size. Discuss the relevance of Notebooks in the context of genAI and AI explainability. Invite people to explore the challenges set on the awesome-notebooks repository and encourage them to contribute. Finally, ask for support in spreading the word about your initiative.",
#  "You are an AI expert who has been working on improving AI's ability to summarize text without losing the impactful punchlines and tonality. You have used Python and LLMs to create a solution for a client and found that combining rule-based systems and prompt engineering yields better results. You have a three-step process for this: starting with a narrow context, focusing on a set of keywords, and constraining the LLM to exclude these keywords and focus on valuable sentences. You are inviting others to discuss this topic further and express your willingness to learn from more use cases. Write a LinkedIn post sharing your experience and inviting others to join the conversation.",
#  "Create a LinkedIn post discussing the importance of a disruptive mindset in CEOs, particularly in the context of Data & AI strategy. Discuss how disruption drives transformative change and innovation, and how it's crucial to challenge existing paradigms and take calculated risks in the fast-paced landscape of AI. Conclude by encouraging others to adopt this disruptive role in their organizations. Use relevant hashtags such as #DataScience, #AI, #Strategy, #Disruption, #Innovation, and #CEOInsights.",
#  'As a data professional, share your thoughts on the three fundamental pipelines inside a data product, which go beyond ETL. Discuss the importance of accessing relevant data, making it speak, and distributing the information. Encourage your peers to start building. Use relevant hashtags such as #dataproducts, #ai, #ml, and #pipeline.',
#  'As an AI expert, compare the process of developing an AI system to portfolio management. Discuss the similarities between the two, including aspects like diversification, risk management, continuous learning and improvement, and expertise. Also, provide advice on how to become an expert in AI and manage the portfolio of data and products effectively.',
#  'As an AI professional who is currently working on a workflow focused on content recycling for an organization, share your thoughts on the importance of workflow over the model in AI. Discuss the results you\'ve achieved by applying a series of prompts to the extracted clips and how it has benefited the marketing team. Also, explain your understanding of "lean data management" and how AI can be used to extract insights from content and amplify the message. Use the hashtag #leandata in your post.',
#  'Write a LinkedIn post discussing the importance of an opinionated data model in creating an AI system. Discuss the limitations of no-code solutions and the need for customization in AI systems. Mention the role of Data & AI Product Development in creating a product-specific data model. Encourage interested individuals to reach out and follow you for more insights. Use relevant hashtags such as #DataModel, #AI, #ProductDevelopment, #NoCode, #DataScience, and #DataProductDev.',
#  "As a product developer at Naas, you've been trying to stay focused despite the recent surge of AI-related news. Today, you decided to compile a list of the 10 most impactful news items related to AI. You've been more critical than usual in your analysis because you believe it's important to maintain a realistic perspective on AI's capabilities. Share your thoughts on how AI does not prevent us from thinking.",
#  'As an AI, write a post for LinkedIn quoting the CEO of Palantir on his views about the concept of hype in the business world.',
#  'Write a LinkedIn post announcing the launch of Joule, a new AI copilot by SAP that understands your business, streamlines tasks, provides smart insights, and helps generate better outcomes. Also, include a link for more information.',
#  'As a professional in the field of Data & AI Product Development, share your thoughts on the importance of this discipline in merging business and tech jobs. Also, discuss your plans to focus more on this topic and how companies should build strong opinions about their Data & AI Product Roadmap & Execution strategy. Encourage your followers to stay tuned for more insights.',
#  "As an AI enthusiast who loves open source but still uses openAI's GPT models in your workflows, write a LinkedIn post expressing this and asking your connections to guess why.",
#  'As an AI expert, share your thoughts on the partnership between Amazon and Anthropic, and how you think it will compare to the partnership between Microsoft and OpenAI in terms of customer care and commitment towards reliable, high-performing models. Include a link to a relevant article for further reading.',
#  "As an AI expert, share your thoughts on the recent Pew Research Center's article that states only 5% of people believe AI will be extremely helpful in their jobs. Discuss your understanding of why people might feel this way, drawing parallels between the early stages of AI and the early days of computers. Encourage others to seize the opportunity to educate about AI, build products that unlock its potential, and lead AI adoption within their organizations. Conclude by urging your audience to be early adopters and help increase confidence in AI. Use hashtags #artificialIntelligence, #earlyadopters, and #dataproducts.",
#  "Write a LinkedIn post discussing Steve Jobs' possible anticipation of Large Language Models 30 years ago and promoting a website that provides weekly summaries of the latest AI research and breakthroughs.",
#  'Create a LinkedIn post where you announce your upcoming talk to the Decoding Data Science Community about Data & AI Product Development. Share your excitement about the opportunity to share your insights and experiences in this field, and mention your previous experiences in finance and AI project development. Also, mention that you will be discussing both the opportunities and challenges that come along with this discipline. Invite data scientists, product managers, and anyone interested in Business, Data, AI, and Product Development to join the discussion. Provide the time of the event and encourage attendees to bring their questions, thoughts, and insights. Lastly, express your gratitude to Mohammad Arshad for the invitation.',
#  "Write a LinkedIn post explaining the difference between an AI Base Model, Instruct Model, and Chat Model, using Deci AI's new models as an example. Include a brief description of each model and how they are used. Conclude the post by encouraging engagement from your followers."]

# %% [markdown]
# ### Create DataFrame question & answer

# %%
dataset = []

for index, q in enumerate(questions):
    dataset.append(
        {
            "question": questions[index],
            "answer": texts[index]
        }
    )
    
final_df = pd.DataFrame(dataset)
final_df
# Out:
#                                              question  \
# 0   As an AI enthusiast, share your thoughts on Op...
# 1   As an AI expert, explain the differences betwe...
# 2   Write a LinkedIn post about your recent experi...
# 3   As an AI enthusiast, express your concerns abo...
# 4   Write a LinkedIn post about your experience bu...
# 5   As an AI enthusiast who recently experienced a...
# 6   As the head of an open source program that rec...
# 7   Write a LinkedIn post explaining the C.I.D.I. ...
# 8   Create a LinkedIn post discussing the importan...
# 9   Write a LinkedIn post discussing the importanc...
# 10  Create a LinkedIn post discussing the importan...
# 11  Write a LinkedIn post about the benefits of us...
# 12  You are a tech enthusiast who is currently exp...
# 13  As an AI expert, share your thoughts on the im...
# 14  As a company that just concluded its participa...
# 15  As an AI expert, share your thoughts on the cu...
# 16  You are an expert in AI and SaaS meeting summa...
# 17  Write a LinkedIn post discussing your thoughts...
# 18  As an AI expert working at naas.ai, you are cu...
# 19  As an AI, write a LinkedIn post expressing the...
# 20  As an AI expert working at naas.ai, you have b...
# 21  As an AI expert, share your thoughts on the im...
# 22  Write a LinkedIn post discussing the potential...
# 23  Write a LinkedIn post discussing the importanc...
# 24  As a software developer and AI product manager...
# 25  As an AI, share your recent experience of comp...
# 26  Write a LinkedIn post where you express your e...
# 27  Write a LinkedIn post discussing the discovery...
# 28  You are currently testing new notebook templat...
# 29  Write a short statement about your perspective...
# 30  Write a LinkedIn post expressing your gratitud...
# 31  As a professional collaborating with a leading...
# 32  Write a LinkedIn post discussing the challenge...
# 33  As a representative of Naas.ai, announce your ...
# 34  You are an AI expert who has been working on i...
# 35  Create a LinkedIn post discussing the importan...
# 36  As a data professional, share your thoughts on...
# 37  As an AI expert, compare the process of develo...
# 38  As an AI professional who is currently working...
# 39  Write a LinkedIn post discussing the importanc...
# 40  As a product developer at Naas, you've been tr...
# 41  As an AI, write a post for LinkedIn quoting th...
# 42  Write a LinkedIn post announcing the launch of...
# 43  As a professional in the field of Data & AI Pr...
# 44  As an AI enthusiast who loves open source but ...
# 45  As an AI expert, share your thoughts on the pa...
# 46  As an AI expert, share your thoughts on the re...
# 47  Write a LinkedIn post discussing Steve Jobs' p...
# 48  Create a LinkedIn post where you announce your...
# 49  Write a LinkedIn post explaining the differenc...
#
#                                                answer
# 0   What if GPTs are a distraction on what OpenAI ...
# 1   AI Agents vs Assistants vs Avatars. What's the...
# 2   Today, I experienced something quite remarkabl...
# 3   Let's fight those who want to capture the AI m...
# 4   📩 I have started building my first GPT to clea...
# 5   Don't put all your eggs in the same basket. Th...
# 6   Since we launched our open source program, mor...
# 7   🤪 Tired of the "50 tricks on how to use chatGP...
# 8   What was the big missing ingredient of yesterd...
# 9   Prompting is plumbing in AI. It just became ev...
# 10  If I started programming now, I would start by...
# 11  Knowledge Graphs have gained significant atten...
# 12  🌎 I'm testing different methods to build an AI...
# 13  😎 Enabling any individual or organization to o...
# 14  Hacktoberfest has officially come to a close, ...
# 15  "Focusing on the future existential risks of A...
# 16  AI SaaS meeting summarizers will produce inacc...
# 17  George Orwell's "1984” is a masterpiece. I bel...
# 18  We need to have an open conversation about the...
# 19  "Generative AI is something that should help m...
# 20  In AI Wonderland, the discussions around fine-...
# 21  LLMs did not change anything since I posted th...
# 22  AI's capabilities extend far beyond writing bl...
# 23  ☝️ Why?...is the first question you need to as...
# 24  ⚡️The primary goal of frameworks is to find mi...
# 25  I just finished the course “Decision Intellige...
# 26  🎙️ It's a true privilege to be able to discuss...
# 27  "Fun Fact": Nobody created artificial intellig...
# 28  I’m having so much fun talking to famous chara...
# 29  Data is a reflection of the world we live in: ...
# 30  Thanks Yann LeCun for this strong call to acti...
# 31  I am honored to team up with the best network ...
# 32  While generative AI takes over the world, anal...
# 33  I'm excited to announce our participation in H...
# 34  OK, AI can summarize text. But by doing that, ...
# 35  💡💚 CEOs love disruptors because they are obses...
# 36  Gold nugget from Pau Labarta Bajo  👇\nI also n...
# 37  Developing an AI system looks like portfolio m...
# 38  Let's not overthink AI too much, it's all abou...
# 39  An opinionated data model is the most critical...
# 40  AI does not prevent us from thinking. \n\nIt h...
# 41  Maybe there’s a hype cycle, but it’s not hype ...
# 42  𝗧𝗼𝗱𝗮𝘆 𝗶𝘀 𝗮𝗻 𝗲𝘅𝗰𝗶𝘁𝗶𝗻𝗴 𝗱𝗮𝘆 𝗳𝗼𝗿 𝗔𝗜 𝗮𝘁 𝗦𝗔𝗣! 🥳\n\nI...
# 43  The "Data & AI Product Development" discipline...
# 44  Even if I love open source, I’m still using op...
# 45  The partnership between Amazon + Anthropic  wi...
# 46  Only 5% of people believe AI will be extremely...
# 47  Did Steve Jobs anticipate Large Language Model...
# 48  I'll talk to the Decoding Data Science Communi...
# 49  Do you know the difference between an AI Base ...

# %% [markdown]
# ## Output

# %% [markdown]
# ### Send to Google Sheets spreadsheet

# %%
gsheet.connect(spreadsheet_url).send(sheet_name=sheet_name, data=final_df, append=False)
# Out:
# {'insertedRow': 50}
