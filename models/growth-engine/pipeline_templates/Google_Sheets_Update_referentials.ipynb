# %% [markdown]
# <img width="8%" alt="Google Sheets.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Google%20Sheets.png" style="border-radius: 15%">

# %% [markdown]
# # Google Sheets - Update Referentials

# %% [markdown]
# **Tags:** #googlesheets #gsheet #data #naas_drivers #operations #snippet

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# **Description:** This notebook allows to send data to Google Sheets to a Google Sheets spreadsheet.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
from naas_drivers import gsheet, linkedin
import pandas as pd
import os
from datetime import date
import naas_data_product
import openai
import time
from googlesearch import search
import re
from difflib import SequenceMatcher
# Out:
# ✅ utils file '/home/ftp/abi/utils/data.ipynb' successfully loaded.
# ✅ utils file '/home/ftp/abi/utils/naas_chat_plugin.ipynb' successfully loaded.
# ✅ utils file '/home/ftp/abi/utils/naas_lab.ipynb' successfully loaded.
# ✅ utils file '/home/ftp/abi/utils/openai.ipynb' successfully loaded.

# %% [markdown]
# ### Setup variables
# **Inputs**
# - `input_dir`: Input directory to retrieve file from.
# - `file_reactions`: Name of the file with reactions to be retrieved.
# - `file_comments`: Name of the file with comments to be retrieved.
#
# **Outputs**
# - `spreadsheet_url`: Google Sheets spreadsheet URL.
# - `sheet_name`: Google Sheets sheet name.
# - `append`: If False, data will be canceled and replaced.

# %%
# Inputs
input_dir = os.path.join(naas_data_product.OUTPUTS_PATH, "growth-engine", date.today().isoformat())
file_name = "linkedin_interactions"
openai_api_key = naas.secret.get("OPENAI_API_KEY")
li_at = naas.secret.get("LINKEDIN_LI_AT") or "YOUR_LINKEDIN_LI_AT" #example: AQFAzQN_PLPR4wAAAXc-FCKmgiMit5FLdY1af3-2
JSESSIONID = naas.secret.get("LINKEDIN_JSESSIONID") or "YOUR_LINKEDIN_JSESSIONID" #example: ajax:8379907400220387585

# Outputs
spreadsheet_url = naas.secret.get("ABI_SPREADSHEET") or "YOUR_GOOGLE_SPREADSHEET_URL"
ref_contacts_name = "CONTACTS"
ref_companies_name = "COMPANIES"
leads_profiles_name = "LEADS_PROFILES"
leads_companies_name = "LEADS_COMPANIES"
append = False

# %% [markdown]
# ## Model

# %% [markdown]
# ### Get BDD interactions

# %%
df_interactions = pload(input_dir, file_name)    
print('🗂️ Interactions:', len(df_interactions))
df_interactions.head(3)
# Out:
# 🗂️ Interactions: 1568
#            ENTITY  SCENARIO  PLATFORM FIRSTNAME LASTNAME         FULLNAME  \
# 0  Jérémy Ravenel  W49-2023  LinkedIn   Abhisek    Nanda    Abhisek Nanda
# 1  Jérémy Ravenel  W49-2023  LinkedIn   Abraham  Cherian  Abraham Cherian
# 2  Jérémy Ravenel  W49-2023  LinkedIn   Abraham  Cherian  Abraham Cherian
#
#                                           OCCUPATION    INTERACTION  \
# 0  Product Owner || Business Analyst || Digital S...  POST_REACTION
# 1  Group Solutions Leader @ Brane | TEDx speaker ...  POST_REACTION
# 2  Group Solutions Leader @ Brane | TEDx speaker ...   POST_COMMENT
#
#                                  INTERACTION_CONTENT  INTERACTION_SCORE  \
# 0                                               LIKE                  1
# 1                                               LIKE                  1
# 2  Great ideas. Some really exciting work already...                  3
#
#                                          PROFILE_URL               PUBLIC_ID  \
# 0  https://www.linkedin.com/in/ACoAAAPlOvYBoVWbeK...  abhisek-nanda-a72a7819
# 1  https://www.linkedin.com/in/ACoAAAG1Qd0B4tWJNT...          abrahamcherian
# 2  https://www.linkedin.com/in/ACoAAAG1Qd0B4tWJNT...          abrahamcherian
#
#                                        CONTENT_TITLE  \
# 0  Almost every CEOs want to build an internal ch...
# 1  Almost every CEOs want to build an internal ch...
# 2  Almost every CEOs want to build an internal ch...
#
#                                          CONTENT_URL  \
# 0  https://www.linkedin.com/feed/update/urn:li:ac...
# 1  https://www.linkedin.com/feed/update/urn:li:ac...
# 2  https://www.linkedin.com/feed/update/urn:li:ac...
#
#              PUBLISHED_DATE         DATE_EXTRACT
# 0  2023-12-04 22:12:53+0100  2023-12-05 11:57:04
# 1  2023-12-04 22:12:53+0100  2023-12-05 11:57:04
# 2  2023-12-04 22:12:53+0100  2023-12-05 11:57:07

# %% [markdown]
# ### Get data "CONTACTS" from Google Sheets spreadsheet

# %%
df_contacts = gsheet.connect(spreadsheet_url).get(sheet_name=ref_contacts_name)
print("CRM Contacts:", len(df_contacts))
df_contacts.head(3)
# Out:
# CRM Contacts: 23839
#   FIRSTNAME LASTNAME     FULLNAME                         EMAIL LINKEDIN_URL  \
# 0     Kudos    ANASS  Kudos ANASS        kudos95anass@gmail.com           NA
# 1        NA       NA        NA NA  aurelien@lesbellesboites.com           NA
# 2        NA       NA        NA NA           jujudu33700@live.fr           NA
#
#   COMPANY                CREATEDATE  CONTACT_ID   OWNER_ID     OWNER_EMAIL
# 0      NA  2023-12-05T11:11:08.968Z      776451         NA              NA
# 1      NA  2023-12-05T10:07:57.366Z      776401  158373005  jeremy@naas.ai
# 2      NA  2023-12-05T10:03:28.723Z      776351         NA              NA

# %% [markdown]
# ### Get data "COMPANIES" from Google Sheets spreadsheet

# %%
df_companies = gsheet.connect(spreadsheet_url).get(sheet_name=ref_companies_name)
print("CRM Companies:", len(df_companies))
df_companies.head(3)
# Out:
# CRM Companies: 4199
#               NAME INDUSTRY        COUNTRY  \
# 0  Lesbellesboites       NA         France
# 1          Appleid       NA  United States
# 2           Prompt       NA             NA
#
#                                          LINKEDINBIO  \
# 0  Les Belles Boîtes is a venture capital and pri...
# 1  Apple is a multinational corporation that desi...
# 2                                                 NA
#
#                                         LINKEDIN_URL  \
# 0  https://www.linkedin.com/company/les-belles-bo...
# 1             https://www.linkedin.com/company/apple
# 2         https://www.linkedin.com/company/promptb2b
#
#                  CREATEDATE   CONTACT_ID   OWNER_ID     OWNER_EMAIL
# 0  2023-12-05T10:07:58.180Z  18320098607         NA              NA
# 1  2023-12-04T21:51:42.705Z  18315850819         NA              NA
# 2  2023-12-04T21:51:41.529Z  18315831358  158373005  jeremy@naas.ai

# %% [markdown]
# ### Get data "LEADS" from Google Sheets spreadsheet

# %%
df_leads = gsheet.connect(spreadsheet_url).get(sheet_name=leads_profiles_name)
print("Leads:", len(df_leads))
df_leads.head(1)
# Out:
# Leads: 848
#   FIRSTNAME LASTNAME          FULLNAME  \
# 0  Jonathan  La Cruz  Jonathan La Cruz
#
#                                           OCCUPATION  \
# 0  Information Technology & Business intelligence...
#
#                                          PROFILE_URL       PUBLIC_ID  \
# 0  https://www.linkedin.com/in/ACoAAAlYSwQBS9GBiC...  jonathanlacruz
#
#    INTERACTION_SCORE           ICP          COMPANY  \
# 0                 80  DataProducer  Finerio Connect
#
#                                                NOTES CRM_CONTACT_ID  \
# 0  Like 'Happy Thanksgiving everyone. 🍁🍂🥧' (https...         663201
#
#   LAST_INTERACTION_DATE                       LAST_CONTENT_URL_INTERACTION  \
# 0          Sun. 03 Dec.  https://www.linkedin.com/feed/update/urn:li:ac...
#
#                       LAST_CONTENT_TITLE_INTERACTION
# 0  I would even say “Good AI requires clean data,...

# %% [markdown]
# ### Get data "LEADS_COMPANIES" from Google Sheets spreadsheet

# %%
df_leads_companies = gsheet.connect(spreadsheet_url).get(sheet_name=leads_companies_name)
print("Leads Companies:", len(df_leads_companies))
df_leads_companies.head(1)
# Out:
# Leads Companies: 321
#   COMPANY_ID  COMPANY COMPANY_NAME                              LINKEDIN_URL  \
# 0   70506391  naas.ai      naas.ai  https://www.linkedin.com/company/naas-ai
#
#    DIRECT_INTERACTIONS  INDIRECT_INTERACTIONS  INTERACTION_SCORE  \
# 0                    0                     61                 61
#
#                INDUSTRY STAFF_COUNT STAFF_RANGE FOLLOWER_COUNT COUNTRY   CITY  \
# 0  Software Development          22        2-10           2986      FR  Paris
#
#                 WEBSITE                                            TAGLINE  \
# 0  https://www.naas.ai/  ⚡️ All-in-one open source data platform\n#lowc...
#
#                                          DESCRIPTION
# 0  Naas is the first Jupyter based data-science p...

# %% [markdown]
# ### Get interactions unique profiles

# %%
def get_unique_profile(
    df_init
):
    # Init
    df_profiles = df_init.copy()
    df_last_interaction = df_init.copy()

    # Groupby profile
    to_group = [
        "FIRSTNAME",
        "LASTNAME",
        "FULLNAME",
        "OCCUPATION",
        "PROFILE_URL",
        "PUBLIC_ID"
    ]
    to_agg = {
        "INTERACTION_SCORE": "sum"
    }
    df_profiles = df_profiles.groupby(to_group, as_index=False).agg(to_agg).drop_duplicates("PROFILE_URL")
    df_profiles = df_profiles.sort_values(by="INTERACTION_SCORE", ascending=False).reset_index(drop=True)
    
    # Add last interactions data
    to_keep = [
        "PROFILE_URL",
        "PUBLISHED_DATE",
        "CONTENT_URL",
        "CONTENT_TITLE"
    ]
    df_last_interaction = df_last_interaction[to_keep].drop_duplicates().drop_duplicates(["PROFILE_URL"])
    
    # Merge dfs
    df = pd.merge(df_profiles, df_last_interaction, how="left")
    to_rename = {
        "PUBLISHED_DATE": "LAST_INTERACTION_DATE",
        "CONTENT_URL": "LAST_CONTENT_URL_INTERACTION",
        "CONTENT_TITLE": "LAST_CONTENT_TITLE_INTERACTION"
    }
    df = df.rename(columns=to_rename)
    df["LAST_INTERACTION_DATE"] = pd.to_datetime(df["LAST_INTERACTION_DATE"].str[:-5]).dt.strftime("%a. %d %b.")
    df = df.sort_values(by=["INTERACTION_SCORE", "LAST_INTERACTION_DATE"], ascending=[False, False])
    return df.reset_index(drop=True)

df_profiles = get_unique_profile(df_interactions)
print("Profiles:", len(df_profiles))
df_profiles.head(1)
# Out:
# Profiles: 953
#   FIRSTNAME LASTNAME          FULLNAME  \
# 0  Jonathan  La Cruz  Jonathan La Cruz
#
#                                           OCCUPATION  \
# 0  Information Technology & Business intelligence...
#
#                                          PROFILE_URL       PUBLIC_ID  \
# 0  https://www.linkedin.com/in/ACoAAAlYSwQBS9GBiC...  jonathanlacruz
#
#    INTERACTION_SCORE LAST_INTERACTION_DATE  \
# 0                 80          Sun. 03 Dec.
#
#                         LAST_CONTENT_URL_INTERACTION  \
# 0  https://www.linkedin.com/feed/update/urn:li:ac...
#
#                       LAST_CONTENT_TITLE_INTERACTION
# 0  I would even say “Good AI requires clean data,...

# %% [markdown]
# ### Update Ref Contact

# %%
prompt_company = """
I will give you the occupation from a profile I get from LinkedIn, you will return the company you can extract from by checking the word after 'at' or '@'.
If you don't find it return "NA"
Don't put the results into quotes.
"""

prompt_icp = """
I have 2 ideal customer profile, one is a 'data producer' with basic knowledge of Python that could use our Notebook templates to create plugins. 
These plugions are then distributed data via our NaasAI Chat interface.
The other one is a 'data consummer' that will enjoy using NaasAI Chat for its basic LLMs integration but also interested in having its own data available, hence work with the data producer. 
I will give you the occupation from a profile I get from LinkedIn, you will return stricly and only one of the following values inside the simple quotes based on the best match 'DataProducer', 'DataConsummer', 'NotICP' or 'NA' if you don't find a plausible match with the first 3 values.
Don't put the results into quotes.
"""

def get_interactions_by_profile(
    df_init,
    contacts
):
    # Init
    df = df_init.copy()
    interactions = {}
    
    # Cleaning
    to_select = [
        "PROFILE_URL",
        "CONTENT_TITLE",
        "CONTENT_URL",
        "INTERACTION",
        "INTERACTION_CONTENT"
    ]
    df = df[to_select].sort_values(by="PROFILE_URL").reset_index(drop=True)
    df["INTERACTION_TEXT"] = ""
    df.loc[df["INTERACTION"] == "POST_REACTION", "INTERACTION_TEXT"] = df["INTERACTION_CONTENT"].str.capitalize() + " '" + df["CONTENT_TITLE"].str.strip() + "' (" + df["CONTENT_URL"] + ")"
    df.loc[df["INTERACTION"] == "POST_COMMENT", "INTERACTION_TEXT"] = "Comment '" + df["INTERACTION_CONTENT"].str.capitalize() + "' on '" + df["CONTENT_TITLE"].str.strip() + "' (" + df["CONTENT_URL"] + ")"

    # Create interactions by profile
    for contact in contacts:
        tmp_df = df.copy()
        tmp_df = tmp_df[tmp_df["PROFILE_URL"] == contact].reset_index(drop=True)
        interests = ""
        for row in tmp_df.itertuples():
            interaction_text = row.INTERACTION_TEXT
            interests = f"{interests}{interaction_text}, "
        interactions[contact] = interests.strip()
    return interactions

def remove_emojis(text):
    # Emoji pattern
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002500-\U00002BEF"  # chinese char
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # dingbats
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    # Remove emojis from the text
    text = emoji_pattern.sub(r'', text)
    return text.strip()

def update_contacts_info(
    df_init,
    df_leads,
    df_contacts,
    input_dir,
):
    # Init
    df = df_init.copy()

    # Filter on profile and concat with leads init
    df = df[df["PROFILE_URL"].str.contains("https://www.linkedin.com/in/.+")]
    df = df.sort_values(by=["INTERACTION_SCORE"], ascending=[False]).reset_index(drop=True)
    df = pd.concat([df_leads, df]).drop_duplicates("PROFILE_URL").fillna("TBD")

    # Cleaning: Remove emojis from name and occupation
    df["FIRSTNAME"] = df.apply(lambda row: remove_emojis(row["FIRSTNAME"]), axis=1)
    df["LASTNAME"] = df.apply(lambda row: remove_emojis(row["LASTNAME"]), axis=1)
    df["OCCUPATION"] = df.apply(lambda row: remove_emojis(row["OCCUPATION"]), axis=1)
    df["FULLNAME"] = df["FIRSTNAME"] + " " + df["LASTNAME"]

    # Enrich: Additional column: ICP, company and notes
    if not "ICP" in df.columns:
        df["ICP"] = "TBD"
    if not "COMPANY" in df.columns:
        df["COMPANY"] = "TBD"
    if not "CRM_CONTACT_ID" in df.columns:
        df["CRM_CONTACT_ID"] = "TBD"
        
    # Create notes from interactions
    leads = df["PROFILE_URL"].unique()  
    df["NOTES"] = df["PROFILE_URL"].map(get_interactions_by_profile(df_interactions, leads))
    
    # Find ICP and Company
    for row in df.itertuples():
        index = row.Index
        fullname = row.FULLNAME
        occupation = row.OCCUPATION
        icp = row.ICP
        company = row.COMPANY
        profile_url = row.PROFILE_URL
        profile_id = profile_url.split("/")[-1]
        public_id = row.PUBLIC_ID
        crm_contact = row.CRM_CONTACT_ID

        # Get ICP
        if icp == "TBD":
            icp = create_chat_completion(openai_api_key, prompt_icp, occupation)
            print(f"{index+1} - 🧑‍💼 '{fullname}' ICP: {icp} ({occupation})")
            df.loc[index, "ICP"] = icp.replace("'", "")
            time.sleep(2)

        # Update Company info
        if company == "TBD":
            company = create_chat_completion(openai_api_key, prompt_company, occupation)
            print(f"{index+1} - 🏢 '{fullname}' Company: {company} ({occupation})")
            df.loc[index, "COMPANY"] = company.replace("'", "")
            time.sleep(2)

        # Find if interaction PROFILE_ID or PUBLIC_ID match with CRM LinkedIn URL then get company name
        if crm_contact == "TBD":
            for x in [profile_id, public_id]:
                tmp_df = df_contacts[df_contacts["LINKEDINBIO"].astype(str).str.contains(x)].reset_index(drop=True)
                if len(tmp_df) > 0:
                    break

            if len(tmp_df) > 0:
                crm_contact_id = ", ".join(tmp_df["CONTACT_ID"].astype(str).unique().tolist())
                if company == "TBD" or company == "NA":
                    crm_companies = ", ".join(tmp_df["COMPANY"].unique().tolist())
                    print(f"{index+1} - 🏢 '{fullname}' CRM Company: {crm_companies} (Company: {company})")
                    df.loc[index, "COMPANY"] = crm_companies
            else:
                crm_contact_id = "NA"
            df.loc[index, "CRM_CONTACT_ID"] = crm_contact_id            
    return df.reset_index(drop=True)
    
df_leads_new = update_contacts_info(
    df_profiles,
    df_leads,
    df_contacts,
    input_dir,
)  
print("Leads updated:", len(df_leads_new))
df_leads_new.head(5)
# Out:
# 6 - 🏢 'William Wied' Company: NA (AI Augmented - Growth Insights & Business Optimization)
# 17 - 🏢 'Marc Cavazza' Company: NA (Professor of AI (posting in a personal capacity))
# 21 - 🏢 'Peter Jeitschko' Company: NA (I help organizations to automate repetitive task with Artificial Intelligence. Anti-AI regulation activist.)
# 27 - 🏢 'Harim M.' Company: NA (I am a Shark)
# 39 - 🏢 'Andrejs Karpovs' Company: NA (I help leaders and individual contributors navigate the AI era)
# 44 - 🏢 'Hanane DUPOUY' Company: NA (Algorithmic Trader, CFA | AI Passionate)
# 48 - 🏢 'Davide Imperati, PhD, CMath, MIMA' Company: NA (Data Engineering, Artificial Intelligence & Data Science, Cloud Migration, Quant Development)
# 52 - 🏢 'Jiajun (Jeff) Lu' Company: NA (Make the world more intelligent and happy.)
# 54 - 🏢 'Ani Panda' Company: NA (Digital Transformation Leadership | Data Strategy, Architecture, Engineering, Governance & Integration | Startup Enthusiast)
# 56 - 🏢 'Emmanuel Oluga' Company: NA (Actualising the Future of Augmented Intelligence)
# 59 - 🏢 'Christine Carragee' Company: NA (Pricing & Analytics)
# 64 - 🏢 'Philippe Larcher' Company: NA (Virtual Teams & Coaching  60x SEO and 4x Revenue Case Studies)
# 67 - 🏢 'Dr. Silas Aslan' Company: NA (Innovation AIchemist - as a chemist, I get it!  (Talk to my new DIGITAL TWIN))
# 72 - 🏢 'Edmond Yang' Company: NA (Creative Tech / Visual artist / Creative Director / Speaker . AI enthusiast)
# 75 - 🏢 'Kelly Cousineau' Company: NA (Helping business owners create their next adventures and make new friends.)
# 76 - 🏢 'Paul V.' Company: NA (Business Sales & Acquisitions - Business Value Growth Consulting)
# 81 - 🏢 'Miley Nakamura' Company: NA (Strategy | Digital | Technical Project Leader | Financial Services)
# 88 - 🏢 'Jan Kulíšek' Company: NA (AI Evangelist | Growth Hacker | I help companies to level up  through AI technologies. I guide you through whole  innovation process | Let me assist you, send me a message)
# 93 - 🏢 'Daniel van Veldhoven' Company: NA (Data-Driven Graphical & Animated Content for Events)
# 95 - 🏢 'Tomy Yoi' Company: EDC Paris Business School Master of Science International Business Program (Student at EDC Paris Business School Master of Science International Business Program #internship #International Business)
# 98 - 🏢 'Alex Kondratiuk' Company: NA (⌲ Turning ideas into thriving products | ⌲ Proven method to increase startup success by 65% | ⌲ 10+ launches in 4 years | ⌲ Podcast host)
# 102 - 🏢 'Matteo Castiello' Company: NA (Researching new stuff that might solve problems | Generative AI | Process Automation)
# 104 - 🏢 'Jonathan Sims' Company: NA (Data Consultant)
# 105 - 🏢 'Sergei Veinberg' Company: NA (Automating Marketing Measurement)
# 106 - 🏢 'Manan Abdul Ahad' Company: NA (AI Strategy Consultant currently helping SMEs embrace AI | SDLC x Agile x Lean | Google Certified Project Manager)
# 107 - 🏢 'Jonathan K.' Company: NA (Artificial Intelligence & Machine Learning)
# 109 - 🏢 'Sean Cheo' Company: NA (Learning about generative AI's applications in marketing)
# 110 - 🏢 'Jason Head' Company: NA (Software Development; robotics project - jasonmhead.com)
# 114 - 🏢 'Tony Carrara' Company: NA (Product Strategy | Product Management)
# 118 - 🏢 'Victor Vivès' Company: NA (Proudly committed to the Ecological Transition!  #GreenTech Networking for Good #NearBound)
# 119 - 🏢 'William Friend' Company: NA (Inspire curiosity, enable happiness, make it happen.)
# 126 - 🏢 'Emmanuel C.' Company: NA (Head of Software R&D . Senior Developer)
# 128 - 🏢 'Pierre C. Bourbonnais' Company: NA (Values, Vision, Results)
# 129 - 🏢 'Pradeep Sanyal' Company: NA (Seasoned CIO & CTO | Data & AI Leader | CIO Advisor | Building AI-first solutions | Advisory Board Member | Ex AWS)
# 133 - 🏢 'Patrick Richter' Company: NA (IT Freelancer | Digital Nomad | Cloud Specialist)
# 134 - 🏢 'Ranjani Murali' Company: NA (MSc in Applied Computing, Department of Computer Science, University of Toronto)
# 135 - 🏢 'Robert DuWors' Company: NA (Digital Substrate Architect with insight from being there.)
# 138 - 🏢 'Patrick Vientos' Company: NA (Data/AI Scientist | Software Engineer/Developer | eDiscovery Expert)
# 140 - 🏢 'Andy Roy' Company: NA (AI consultant helping clients design and build AI-powered business applications)
# 142 - 🏢 'Ralph Case' Company: NA (Leading Engineering teams to deliver quality Data and Software Systems)
# 145 - 🏢 'Bill Karwin' Company: NA (Internal server error.)
# 146 - 🏢 'James M. Dey' Company: NA (Data, info & now even knowledge has been commoditised. Seek wisdom.)
# 148 - 🏢 'Mahtab Syed' Company: NA (IT Leader | Consulting, People, Program, Technology and Revenue | Deliver Data Engineering, Machine Learning, Artificial Intelligence and MLOps Programs | Generative AI | On Cloud (Azure, AWS) | Love Coding and Kaggle)
# 150 - 🏢 'Jeremy ARANCIO' Company: NA (NLP Engineer | Freelance)
# 152 - 🏢 'Allauddin Khan Pathan TBD' Company: NA (Data Engineer [Bigdata with Spark]™ 19K+ Followers22M+ Impressions Skills: SparkHiveBigdataHadoopSqoop MRYarnLinuxMysqlPysparkHdfsHQL. MCA with Distinction)
# 154 - 🏢 'Charmie Ranodya' Company: NA (Data Engineer | Content Writer | Technical Writer)
# 157 - 🏢 'Javier H.' Company: NA (Hardware, Software, Security)
# 159 - 🏢 'Jennifer McIntosh' Company: NA (Chapter Lead - Chatbot Conversation Design)
# 160 - 🏢 'Islam Salahuddin' Company: NA (Data Analyst | Certified Practitioner and Facilitator)
# 162 - 🏢 'Joseph M.' Company: NA (Tell me about your hardest problems. edtech, ml/ai, big-data systems, industrial automation, safety/security, ssi)
# 165 - 🏢 'Kristin B.' Company: NA (Product Director / Marketplaces / AdTech / Media / IT / B2B / ex-Microsoft & Adobe / GenAI student / post ipo / late stage startup)
# 170 - 🏢 'Chrystalla I.' Company: NA (TBD)
# 184 - 🏢 'Ed Waters' Company: NA (Senior Business Analyst)
# 185 - 🏢 'Gomathivinayagam Muthuvinayagam' Company: NA (Product builder)
# 201 - 🏢 'Dipty Ranjan Padhy' Company: NA (Senior Director - AI, Cloud, Data & Analytics Strategy| MIT Certified Artificial Intelligence professional)
# 202 - 🏢 'Abdullahi Yunus' Company: NA (Software Engineer | Data | Bitcoin developer | JavaScript | TypeScript | Python)
# 203 - 🏢 'Yashas Devasurmutt' Company: NA (Computational Biology|Multiomics|Artificial Intelligence|Data Science)
# 207 - 🏢 'Abubakar Khalil' Company: NA (BSc | MA | M.Ed. | CELTA | Doctoral Student AU - English Teacher - IELTS Trainer - Second Language Education - Distance Education - Educational Technologies.)
# 208 - 🏢 'Adhiguna Mahendra' Company: NA (Chief of AI and Business|AI Engineer|Author|PhD Machine Learning&Computer Vision)
# 209 - 🏢 'Adrian Blant' Company: NA (Senior Data Governance Architect)
# 210 - 🏢 'Agnieszka Mikołajczyk' Company: NA (AI passionate working on LLMs)
# 211 - 🏢 'Ahmed A.' Company: NA (Australia | Governance | Risk Management Frameworks | Cyber/Info/Data Security | Data Centres | Technology Project Management and Mitigations)
# 212 - 🏢 'Ahmed M. Hussein' Company: NA (Data Scientist | AI Engineer)
# 217 - 🏢 'Tim McCarthy' Company: NA (PMI-PBA, PMI-ACP, Advanced Analytics Professional and Agile Practitioner)
# 219 - 🏢 'Tom Coyle' Company: NA (Distilling complex problems into easily understood solutions. I'm the guy who gets things done while keeping my eye on the strategic vision and goals, all while bridging the worlds of technologists and decision makers.)
# 221 - 🏢 'Tais Sandal Nissen' Company: NA (Conversational AI & BI Manager)
# 222 - 🏢 'Ariraju SankaraNarayanan' Company: NA (ஃ Data Science Student in Linguistics. ஃ)
# 223 - 🏢 'Armando A.' Company: NA (Venture Builder | Growth)
# 227 - 🏢 'Antriksh Agarwal' Company: NA (This Machine is still Learning..)
# 229 - 🏢 'Anum Jamil' Company: NA (NLP Engineer| Machine Learning Engineer| Deep Learning Engineer |Tensorflow Developer|Python)
# 230 - 🏢 'Alexandre de Spindler' Company: NA (Computer Scientist and Teacher | I Help Design, Prototype, and Validate Language-Based Interactions.)
# 231 - 🏢 'Alejandro Manzanos Garcia' Company: NA (Software Developer)
# 232 - 🏢 'Anvay Vats' Company: university (I'm at university.)
# 233 - 🏢 'Anvesh Rao Nadipelli' Company: NA (Data Analyst | Business Intelligence Engineer | Applied Data Science)
# 237 - 🏢 'Ariel Catalá Valencia' Company: NA (Software Engineer | AWS  Cloud Practicioner | Serverless  passionate | Data  Engineering  lover)
# 238 - 🏢 'Alfredo Di Nuccio' Company: NA (Data Scientist)
# 240 - 🏢 'Alice Desthuilliers' Company: NA (Human Computation - Data Ops - AI)
# 241 - 🏢 'Allan Feitosa' Company: NA (PhD, Data Scientist | Natural Language Processing Engineer | Generative AI)
# 242 - 🏢 'Alex Thomas' Company: NA (Data Engineering Manager who stewards technical systems of intelligence in health and human services)
# 243 - 🏢 'Alex Vesa' Company: NA (Senior AI Engineer | Code Architect | MLOps | Contractor - Deep diver into complex AI paradigms for over a decade.)
# 244 - 🏢 'Alexandre Barros' Company: NA (Blockchain Consultant and Tech Advisor)
# 246 - 🏢 'Federico Curiale' Company: NA (Data Scientist)
# 248 - 🏢 'Florent J.' Company: NA (Machine Learning Engineer and Data Engineer Freelance)
# 252 - 🏢 'Essam Ahmed' Company: University of Waterloo (CS at University of Waterloo | Seeking 4-month Internship Winter 2024)
# 254 - 🏢 'Diego Chinellato' Company: NA (CS Teacher | AI Student)
# 255 - 🏢 'Diego Lopes' Company: NA (Data Engineer)
# 258 - 🏢 'Dinesh Gaddi' Company: NA (Data Scientist)
# 260 - 🏢 'Farzan Beroz' Company: NA (AI/ML Data Scientist)
# 261 - 🏢 'Fausto Albers' Company: NA (GenAI app Dev | Speaker | Conversational AI | Hospitality)
# 265 - 🏢 'Dmytro Druzhniev' Company: NA (Looking for a job | Software Developer | Full stack Developer | JavaScript, TypeScript, React, Node.js, Express, Mongo.DB, PHP)
# 268 - 🏢 'Dr. Kathleen K.' Company: NA ("A candle loses nothing of its light when lighting another." Kahlil Gibran)
# 269 - 🏢 'Dhruv lunawath' Company: NA (AI, ML, Data Science Enthusiast | Aspiring Entrepreneur | Exploring the Intersection of Technology and Innovation)
# 271 - 🏢 'Beat Meyer' Company: NA (Connecting People, Organisation and Technologies - #imagination #interconnections #interdependences #insights #impact #COIN #sensemaking)
# 272 - 🏢 'Nico Van de Venne' Company: NA (Here te serve by Empowering Successful Entrepreneurs to forge lasting legacies: Transforming their success into an enduring and lasting impact)
# 273 - 🏢 'Kiah Hewitt' Company: NA (Software Engineer & Website Manager | Frontend React Developer, Web Development, Google Analytics)
# 278 - 🏢 'Giridhar Vadhul' Company: UCSC (B.S. CS @ UCSC | Former Research Intern at Tech4Good @ UCSC)
# 280 - 🏢 'Daniel Danilo Cuevas Mendez' Company: NA (Data Engineer | Data Science | Machine Learning | PySpark | ETL | Datalake | Airflow | Cadence | Dagster | Automatation | Docker | Python | SQL | Dgraph | Java Script | Golang | C / C++ | Google Cloud | AWS | Visa TN)
# 281 - 🏢 'Daniel Enrique Carhuas Canchumanya' Company: NA (Bachiller Ciencias Estadística Informática)
# 284 - 🏢 'Danil Meresenschi' Company: The University of Chicago (Data Engineer | MS in Applied Data Science at The University of Chicago)
# 285 - 🏢 'Daria Sanchez' Company: NA (Macro Social Work | Social Services | Digital Marketing | Social Media | Arts & Business | Content Creation | Web Design | Executive Business Administrator | AI & Prompt Engineering Enthusiast)
# 287 - 🏢 'Goutham Nivass' Company: NA (Dreamer | Go Getter | Tech Grad)
# 289 - 🏢 'GianPiero Pavesi' Company: NA (Cloud Data Architect and MLOps Engineer)
# 292 - 🏢 'Giorgio Moretti' Company: NA (Data and AI Strategy - MSc, PMP, TOGAF)
# 295 - 🏢 'Ela Popardowska' Company: NA (Future-proofing & Business Innovation Consultant • Helping companies increase efficiency & save money on teams by using AI & automation tools)
# 298 - 🏢 'Elizabeth Belinskaya' Company: NA (Art Direction, Creative Concepts & Fashion Design :))
# 301 - 🏢 'Gokul Raja' Company: NA (AI Innovator | Transforming Industries with Intelligent Solutions)
# 302 - 🏢 'Eugene Zilberman' Company: NA (Cloud and Identity Security Architect)
# 303 - 🏢 'Evgeny Tyrtyshny' Company: NA (Senior Project Manager)
# 306 - 🏢 'Farid ABDI' Company: NA (Information Technology Engineer)
# 309 - 🏢 'Erin Fay' Company: NA (Business Expansion: Operations & Strategy | Start-Ups & Emerging Industries | JD/MBA)
# 310 - 🏢 'German Malvestiti' Company: NA (Senior Software Developer/Data Engineer/Big Data Development)
# 314 - 🏢 'Gabriele Giuffredi' Company: NA (Enterprise Data Architect & Governance)
# 315 - 🏢 'Gabriele Mattesini' Company: NA (Alliance Manager)
# 316 - 🏢 'Gajanen Karunananthan' Company: Informatics Institute of Technology (IIT) (BIS undergraduate at Informatics Institute of Technology (IIT))
# 319 - 🏢 'Ed Hodapp' Company: NA (Software should be like air.)
# 320 - 🏢 'Gladys Nana Tchakothe' Company: NA (I share the best data analyst tips | power Bi | SQL | Python | Excel)
# 322 - 🏢 'Geanderson Lenz' Company: NA (AI Engineer)
# 323 - 🏢 'George Pampoukis' Company: NA (Early Stage Researcher - PhD student)
# 326 - 🏢 'Daniel Saldanha' Company: NA (Data Engineer | Data Architecture | GCP Data Engineer | SQL | Python | ETL | Airflow | Docker)
# 327 - 🏢 'Edgars Sīklis' Company: NA (Manager of Compliance Analytics & Intelligence | FinCrime Technology | Data & Analytics)
# 329 - 🏢 'Edward R. Merchant' Company: NA (Senior Executive Leader/Architect/Advisor specializing in transformation, adoption, and optimization of Digital and AI driven businesses)
# 332 - 🏢 'Dr. Thomas Link' Company: NA (Generative AI and Innovation Management Expert | Dr.-Ing., Product Development, Digital Transformation)
# 335 - 🏢 'Darwin joan Perez Avendaño' Company: Universidad de Antofagasta (Estudiante en Universidad de Antofagasta)
# 337 - 🏢 'Daan Tuijnman' Company: Platform & Technologies (Data at Platform & Technologies)
# 338 - 🏢 'Daniel Funes' Company: NA (Systems engineer)
# 340 - 🏢 'Daniel M.' Company: NA (Experienced Reporting & Data Analyst in Banking Industry  SAS & SQL Developer)
# 349 - 🏢 'Jack Gierlich' Company: NA (Impact-First | Growth Nerd | Ensuring Equal Access to Cancer Treatment)
# 355 - 🏢 'Gus Molina' Company: NA (Wellness Anywhere!)
# 356 - 🏢 'Gwendolyn Gillingham' Company: NA (Experienced Data Scientist and Data Science leader seeking new opportunities. Passionate about language and social justice!)
# 357 - 🏢 'Gwendolyn Denise Stripling, Ph.D.' Company: NA (AI/ML | Data & Analytics | Speaker | Author: O'Reilly - Low-Code AI: A Practical Project-Driven Introduction to Machine Learning)
# 360 - 🏢 'Hasan Khan' Company: NA (ML Engineer)
# 361 - 🏢 'HARIYANTO kratom west borneo AKA basule' Company: NA (Berkuliah di tidak ada)
# 363 - 🏢 'Hader Azzini' Company: NA (Tech Manager | Sr Tech Lead | Data Scientist | Solutions Engineer | Data Product)
# 364 - 🏢 'Hakan Tas' Company: NA (Front-end web developer with 5+ years of experience. Open to new projects and consultancy services. JavaScript | ReactJS | Web Development | WordPress | Sanity | TailwindCSS)
# 365 - 🏢 'Hamza Afzal' Company: NA (Data Annotator | Data Science and Artificial Intelligence trainee | Data Analyst | AI Engineer enthusiast)
# 366 - 🏢 'Heather Saul' Company: NA (Communications consultant)
# 367 - 🏢 'Hector Adrian Cardenas Camacho' Company: NA (Data Analyst - Power BI Developer / Business Intelligence / SAP ABAP Developer Reports)
# 368 - 🏢 'Hemant Sawant' Company: NA (Director, S/w Engg | App Dev Leader | InfoSec | Architecture | Microservices | Cloud | Cyber Security | Data | Speaker | Agile)
# 369 - 🏢 'Henry C.' Company: NA (OneReach.ai)
# 370 - 🏢 'Hesam Ghiasi' Company: NA (Java developer | NLP researcher)
# 372 - 🏢 'Himanshu Pareek' Company: NA (Platform support | Full stack AI ML | Customer Success)
# 374 - 🏢 'Jessica Talisman' Company: NA (Top Data Architecture VoiceBuilding information systems for the benefit of all | Taxonomy | Ontology | InfoSci)
# 376 - 🏢 'Jimmy Pantia Huamán' Company: NA (Economista|MOS Associate 2019|MOS Excel Expert|PowerBi|)
# 377 - 🏢 'Claudio Bareato' Company: NA (Internal Auditor spec. in Information Security and Compliance | Engineer, Senior Member IEEE | HBR Advisory Council | Innovation Advisor | Cybersecurity & Emerging Tech writer on LinkedIn)
# 381 - 🏢 'Christina Yang' Company: NA (Technology & Creativity, Human-Computer Interactions, Human-AI-Interactions, Entrepreneurship)
# 386 - 🏢 'Jomar R.' Company: NA (Data Analyst | Power BI | Power Automate | Project Intelligence | RPA | Sales Operations)
# 387 - 🏢 'Jeremiah (Jay) Williams' Company: NA (Computer Scientist)
# 390 - 🏢 'Homer Hegedus' Company: NA (Technical Project/Program Management | New Product Development (NPI) | Workflow Optimization | Data Product Management)
# 394 - 🏢 'Ian M.' Company: NA (Victoria Per Observatiam - Guest on Vasco Duarte’s “Scrum Master’s Toolbox” Podcast!)
# 396 - 🏢 'Jitendrasinh Thakor' Company: NA (Global Business Consultant working globally with Android | IOS | Flutter | Swift | Ionic | Chatbot | AI/ML | IoT.)
# 397 - 🏢 'Jithesh Vijayakumar' Company: NA (B.A. LL.B. (Hons.) || IAPP Member || Data Privacy || Cyber Security || AI Ethics || Responsible AI)
# 401 - 🏢 'Ikram Zouaoui' Company: NA (Data engineer)
# 402 - 🏢 'Ilya Petoushkoff' Company: NA (Strategic transport planning | Public Transport Networks & Infrastructure | Street Design and Public Spaces | Interchange hubs & TOD)
# 403 - 🏢 'Imtiyaz Ali' Company: NA (Analytics-All)
# 406 - 🏢 'Jason Miles' Company: NA (Dreamer of Data Dreams)
# 407 - 🏢 'Jason Scheirer' Company: NA (I am capable of writing software)
# 408 - 🏢 'Javier Díez Pérez' Company: NA (Data Product Lead Oncology)
# 413 - 🏢 'Karen Wallace' Company: NA (Manager specializing in public health and data science)
# 414 - 🏢 'David Gonzo Gonzalez' Company: NA (Talks about AI, complimentary and alternative medicine practitioners & seekers, #psychedelics , and human performance.)
# 421 - 🏢 'Jenny Hurn' Company: NA (People-Oriented Leader  Community Cultivator  Culture Champion  DEIB Advocate  Creative Writing Enthusiast  aPHR)
# 422 - 🏢 'Deepak Paramanand' Company: NA (Shipping AI Products | Generative AI | Responsible AI | Computer Vision | Natural Language Processing | StandUp Comedian)
# 424 - 🏢 'Denis PRODHOMME' Company: NA (#Gestionnaire paie #Nocode fan #Notion fan and Coda too)
# 425 - 🏢 'Derlis Cabrera' Company: NA (Product Analyst | E-commerce, Fintech, and Innovation | Cloud, Python & Javascript learner)
# 432 - 🏢 'Charles Anaman' Company: NA (Banking Services \ Computer Engineer \ Network Engineer \ Web\Cyber Security \ Tech - Tutor \ Future Farmer \ Cloud Engineer)
# 436 - 🏢 'Deb Ghosh' Company: NA (Lifelong Curious, Lifelong Learner)
# 438 - 🏢 'Mandil Karki' Company: NA (NLP Software Engineer | Generative AI | ML Ops | Artificial Intelligence |)
# 441 - 🏢 'Lucien Koefoed' Company: NA (Again, faster)
# 443 - 🏢 'Luis Emanuel Varela' Company: NA (Safeguard your business with human-focused security. Our solutions unite advanced technology and expertise to simplify defense while maximizing protection. Let's craft an effective solution tailored to your priorities.)
# 444 - 🏢 'Maaike Groenewege' Company: NA (Prompt engineering | Conversation design | Linguistics | NLU/NLP | qwertyploinking | I build communities)
# 447 - 🏢 'Jon Saltzman' Company: NA (Living at the intersection of people, systems & data)
# 448 - 🏢 'Jonas Høgh Kyhse-Andersen' Company: NA (Data Scientist - Python enthusiast - Backend developer - MLOps - Podcast)
# 449 - 🏢 'Jose Garcia' Company: NA (Process Engineer | Data Analyst | Optimizing Industrial Processes since 2011)
# 450 - 🏢 'Mahdi Ebrahimpour' Company: NA (Data Engineer, MLOps, NLP/LLM/GNN/CV)
# 452 - 🏢 'Majid Eslami' Company: NA (--)
# 454 - 🏢 'Justin M.' Company: NA (Software Developer - C# Python AI ML)
# 458 - 🏢 'Jose Miguel Seoane' Company: NA (Emerging Technologies | Sustainability)
# 459 - 🏢 'Josh Edmondson' Company: NA (Helping organizations set 'Data in Motion' to operate in real-time via cloud-native hybrid solutions!)
# 461 - 🏢 'Juan Daniel Vargas' Company: NA (Data Analyst - IT Guy)
# 462 - 🏢 'Karin Golde, PhD' Company: NA (AI Strategy & Innovation Expert | Linguistics PhD | Keynote Speaker)
# 463 - 🏢 'Kasturi Pal' Company: Cognizant (MS in Business Analytics| Carlson School Of Management | University Of Minnesota |AI /ML /Data Product Management |Ex-Cognizant)
# 464 - 🏢 'Katie Ravenwood' Company: NA (Product Manager | Data Analyst | Certified ScrumMaster®)
# 468 - 🏢 'Julio Renteria' Company: NA (Lead Data | Architecture & AI | Azure & AWS | Snowflake & Cloudera)
# 471 - 🏢 'Bilge KAYALI' Company: NA (Information Technology Supervisor | Database Administrator)
# 475 - 🏢 'Bradley Flemming' Company: NA (Pre-Sales / Sales Engineering Specialist)
# 477 - 🏢 'Brenda Gavilán Domínguez' Company: NA (Lingüista Computacional)
# 478 - 🏢 'Max Rascher' Company: NA (Helping you leverage AI in the workplace - daily.)
# 479 - 🏢 'Maxime Grosset' Company: NA (Payment I Identity I M&A / Corp. dvpt.)
# 481 - 🏢 'Martiniano ("Marty") Mallavibarrena Martínez de Castro' Company: NA (Cloud, RPA-Automation, AI, CyberSecurity and Criminal investigations. Hooked on retrocomputing.)
# 482 - 🏢 'Marwane Mezzane' Company: NA (Data Analyst - BI - Big Data)
# 489 - 🏢 'Konstantinos Parisopoulos' Company: NA (Lead Content Architect & Generative AI Specialist)
# 496 - 🏢 'Kumuthu Premalal' Company: NA (Medical Undergraduate)
# 497 - 🏢 'Kyle Godbey' Company: NA (Service Designer • Transformation Strategist • Complexity Coach • Sense-Making Partner • Wicked Problem Enthusiast)
# 498 - 🏢 'Kesiena Edor' Company: NA (prompt engineer, Machine learning engineer, dataset curator ,Knowledge engineer, A prolific Chatbot creator, Marketing Technologist , Workflow automation, Python programmer, cloud developer, conversant with heroku,AWS)
# 499 - 🏢 'Ketan Solanki' Company: NA (Data Strategy | Product Management | Advanced Analytics and Machine Learning)
# 503 - 🏢 'Martin Šafránek' Company: NA (Data Vault 2.0. certified data engineer (by Scalefree and DataVaultAliance) with interest in Snowflake and AI)
# 507 - 🏢 'Manuel C.' Company: NA (Jefe de Inteligencia Comercial)
# 508 - 🏢 'Manuel MARTIN' Company: NA (Projects | Lean Six Sigma | Data | Industry 4.0)
# 511 - 🏢 'Matt Lock' Company: NA (Director of Product + Engineering)
# 512 - 🏢 'Marcel De Sutter' Company: NA (Data & AI Specialist)
# 514 - 🏢 'Mariano Chicatun' Company: NA (Machine Learning Engineer | Digital Transformation & PI System Consultant | Electronics Engineer | Machine Learning • Artificial Intelligence • Applied Predictive Modeling)
# 516 - 🏢 'Marion Brisset' Company: NA (Salesforce Solution Architect)
# 517 - 🏢 'Marion Coutarel' Company: NA (Data analyst / RPA - Taming datas  so they reach their true potential)
# 518 - 🏢 'Claudio Valderrama' Company: NA (C++, Delphi, SQL, C#, efficient code, SOA, source code analysis, relational DB, cognitive systems (Watson).)
# 519 - 🏢 'Clemens Timmermans, MSc.' Company: NA (SMB/B2C | Marketplaces | Tech | Advertising | Gen AI)
# 522 - 🏢 'Corey Hence' Company: NA (Dad | Sr Digital Fraud Strategy Leader | Six Sigma Green Belt | Toastmaster Member |)
# 523 - 🏢 'Christoffer Dahl Rexen' Company: NA (Problem Solver/Out of the Box thinker with a passion for Cloud Engineering, DevOps, Solutions Architecture and a Get Things Done attitude  christofferrexen@gmail.com)
# 526 - 🏢 'Benjamin Sombi' Company: NA (Data Scientist| Entreprenuer| Economic Inclusion Evangelist)
# 528 - 🏢 'Bernard Adjei' Company: NA (MATLAB Developer | Machine Learning and AI | Researcher | Tinkering)
# 531 - 🏢 'Bijo Babu' Company: NA (Full stack developer)
# 532 - 🏢 'Bilal A. Chaudhry' Company: NA (Data Science & Advanced Analytics)
# 535 - 🏢 'Nezahat A.' Company: NA (Senior Technical Project Manager)
# 536 - 🏢 'Nickson Mwamsojo, Ph.D.' Company: NA (Data scientist | ML & AI researcher | Ph.D. in Neuromorphic Computing)
# 538 - 🏢 'Nicolas Muriel' Company: NA (Data & Analytics Lead | Empowering teams through data analytics)
# 539 - 🏢 'Nicolás Lecaros Marchant' Company: NA (Principal Data Architect | Instructor | AWS Community Builder | GDG Organizer | Google Cloud Champion Innovator | Certified in AWS, GCP and Azure | FinOps Certified Practitioner | FinOps Certified Engineer)
# 540 - 🏢 'Nikolas Ciminelli' Company: NA (AI Research Scientist | PM | MS in Computer Science)
# 544 - 🏢 'Miguel Marina' Company: NA (Staff System Safety Engineer | Robotics Engineer | Cross-Industry (Autonomous Trucking, Automotive, Aerospace & Semiconductors) & Cross-Domain (SYS, SW, HW & ME) Engineering Expert | ISO/SAE U.S. TAG Committee member)
# 546 - 🏢 'Mayank Swaroop' Company: NA (Data Science Manager)
# 549 - 🏢 'Melvin A.' Company: NA (Transforming Data into Actionable Business Strategies | Business Intelligence Architect | Data Engineering Consultant |)
# 551 - 🏢 'Milan Pandya' Company: NA (Developer | Python | SQL | AWS)
# 553 - 🏢 'Minggang Yin' Company: NA (CFD)
# 554 - 🏢 'Mitesh Yadav' Company: NA (Leveraging AI to solve complex problems and optimize business outcomes)
# 556 - 🏢 'Michael Spicer (MTF)' Company: NA (Metaverse Strategist ( Neuroatypical))
# 557 - 🏢 'Michael Yahaya' Company: NA (Engineering value from data | Data Analytics | Cloud Data Platforms | Murex| Trading & Risk Management | AI & ML Data Management | MLOps & CI/CD | Agile Project Delivery |)
# 558 - 🏢 'Mithil Damani' Company: University of Waterloo (CS @ University of Waterloo)
# 559 - 🏢 'Mithun Kumar' Company: NA (SAP S/4 HANA Architect | Nature Photographer | SAP Technology Advisor | Passionate about Intelligent Business)
# 560 - 🏢 'Mohamed Nogot' Company: NA (Full Stack Developer | Java and ReactJS Enthusiast | Building Seamless Web Solutions | Versatile Multilingual Professional)
# 561 - 🏢 'Mohammad Reza Khalili Shoja' Company: NA (DATA & APPLIED SCIENTIST | PhD | AI, NLP, ML)
# 564 - 🏢 'Mohd Kaif' Company: NA (Data Nerd | NLP | LLMs | Generative AI | Information Retrieval | Semantic Search)
# 566 - 🏢 'Pedro Nunes' Company: NA (Data Analyst | Business Analyst)
# 567 - 🏢 'Pablo Andres Sandoval Morales' Company: NA (hablemos sobre innovación tecnológica.)
# 569 - 🏢 'Patrick Buchholz' Company: NA (cyberspace defender | technology podcaster)
# 572 - 🏢 'Olivier Fortin-Gagnon' Company: NA (Économiste)
# 576 - 🏢 'Mushahid Omer' Company: NA (Business Analyst | Data Analyst | Data Scientist)
# 578 - 🏢 'Paulo Cysne Rios Jr.' Company: NA (Data Science Leader | 21,400+ followers | Transforming businesses with Data Science)
# 579 - 🏢 'Pearling Lim' Company: NA (I Help DTC Founders Hack and 10X Their Online Presence with Strategic Branding & Persuasive Copy | Brand Strategist & Copywriter)
# 583 - 🏢 'Ményssa Cherifa-Luron, PhD • Data Scientist' Company: NA (Je parle de Data Science et al. Newsletter : Coulisses du Clavier)
# 585 - 🏢 'Nabil Abdoun' Company: NA (Doctor of Computer Engineering | Automotive Cybersecurity | Artificial Intelligence for Model-Based Systems Engineering | Human Resources Management)
# 586 - 🏢 'Nabin Acharya' Company: NA (Software Product Architect | Cloud Architect)
# 588 - 🏢 'Muhammad Alif R.' Company: NA (Student of Electronical Engineering | Full Stack Machine Learning Engineer)
# 589 - 🏢 'Muhammad Ammar Tanweer' Company: NA (ML Engineer || Computer Vision Engineer || Devops || Web2 || Web3 Dev || Backend Developer)
# 592 - 🏢 'Nandita Saini' Company: NA (Manager - AI & Cognitive Operations(& Always a Data Scientist))
# 593 - 🏢 'Naveen Manikandan' Company: NA (Entrepreneur | Artificial Intelligence | Internet of Things (IOT) | Data engineer)
# 594 - 🏢 'Nayeem Chaudhury, MSDA' Company: NA (Data Analyst | Business Intelligence | SQL | Power BI | Excel | Python | Azure Data Factory)
# 595 - 🏢 'Neelank Tiwari, MS, PMP' Company: NA (Program Manager | Supplier Management, Medical Device Auditor, AI)
# 599 - 🏢 'Asim Hameed Khan' Company: NA (Machine Learning Engineer |> Deep Learning |> Computer Vision |> Image Processing |> Satellite Imagery |> Time Series |> MLOps |> Cloud |> Backend Development)
# 600 - 🏢 'Attila Konkol, PhD' Company: NA (Data Governance Lead)
# 602 - 🏢 'Augustin LEDUC' Company: NA (DATA & IA Partner | Business & Delivery)
# 604 - 🏢 'Avinash Srivastava' Company: NA (Lead Data Engineer/ Analyst)
# 610 - 🏢 'Prerak Chintalwar, Data Scientist' Company: NA (Experienced Data Scientist | Transforming Complex Data into Insights | Machine Learning, Analytics & Statistical Analysis | Python, R, SQL | Power BI, Tableau)
# 611 - 🏢 'Prerana Jakhotia' Company: NA (Senior Product Manager, Data & AI Products)
# 615 - 🏢 'Prof. Dr.-Ing. Reinhard Moratz' Company: NA (Professor in GeoAI)
# 617 - 🏢 'Radu Ionut Robu' Company: NA (Senior Data Scientist)
# 618 - 🏢 'Rahul G' Company: NA (Exploring Intersections - Tech, Business, Society, Data, Stories, and Everything In Between | Seeking new opportunities in the domain of Data Science & Analytics)
# 619 - 🏢 'Rajasekar Venkatesan, Ph.D.' Company: NA (Data Science Leader | Empowering Business Innovation with Advanced AI Capabilities)
# 620 - 🏢 'Olotu Samuel Eghagha' Company: NA (Cloud Consultant)
# 621 - 🏢 'Onur Karayalcin' Company: NA (Data Engineer | Quantum Computing)
# 624 - 🏢 'Nilos Psathas' Company: NA (Full-Stack Developer, seeking for new adventures)
# 626 - 🏢 'Peter Pollmanns' Company: NA (Conversational AI/UX Designer/Developer)
# 629 - 🏢 'Roberto Sheldon' Company: NA (Data Analyst | Quality Management | Metallurgical Engineer | Power BI |)
# 630 - 🏢 'Robyn Hirano' Company: NA (Customer-centric  Data-driven  Agile  Reliable product management)
# 631 - 🏢 'Rod Rivera' Company: NA (The AI Engineer - Follow me to learn about building AI apps and becoming a GenAI Engineer | Build LLM Apps | Understand Foundational Models | Create AI Products)
# 632 - 🏢 'Rodrigo Callalli Villalta' Company: NA (Industrial Engineer | Supply Chain Management | SAP Hanna and TMS Power User | Supply Chain Data Steward)
# 633 - 🏢 'Bậc Thầy Mr. Bill' Company: NA ((Thou art/Thee) Patriarch; Expert everything Việt Nam; Education; Unabridged Universal Language; AI Arguer; IP Renegade; Clown World Conductor; Monkey King Incarnate - ɝð<>[Feeder job: Thầy Giáo Tiếng Anh])
# 636 - 🏢 'Phyllis Purity Mburu' Company: NA (Financial planning partner/ educator)
# 643 - 🏢 'Chad Collins' Company: NA ((my statements on Linkedin are my own) - Preparing a Shoe Drive this Christmas in Baja California - come and join us!)
# 644 - 🏢 'Brian H.' Company: NA (CFO, CPA, CMA, CFA, MBA)
# 645 - 🏢 'Brian Lim' Company: NA (DevSecOps Architect | ML Enthusiast)
# 649 - 🏢 'Arvis Strods' Company: NA (Risk & Analytics)
# 653 - 🏢 'Carla Rudder' Company: NA (Data Scientist | Python | SQL | Visualization | Certified Scrum Master | Making sense of your data)
# 656 - 🏢 'Cem Yılmaz' Company: NA ("Innovator at the Intersection of Finance and Technology | Founder of Turkey's First Physical Crypto Exchange Store | Driving AI-Powered Simulation Environments")
# 657 - 🏢 'Sachin Tripathi' Company: NA (Data Science Trainer and Future Skills Advocate: Empowering Learners to Thrive in the Age of Automation)
# 666 - 🏢 'Sandhya Gopal' Company: NA (Empowering RE Investors and Businesses for Financial Efficiency | Real Estate Enthusiast | Personal Finance Education Advocate)
# 668 - 🏢 'Sanjin Lisic' Company: NA (Product Manager - Platform Communications)
# 670 - 🏢 'Sara Ivanyos' Company: NA (Data Engineer)
# 672 - 🏢 'Sabahudin Murtic' Company: NA (AI Market Shaper: Unlocking New Markets & Opportunities • Transform Your Ideas into Profits with AI)
# 673 - 🏢 'Reza Afshar' Company: NA (3D hard surface artist for fun)
# 675 - 🏢 'Riad Habash' Company: NA (Business Intelligence Solutions Architect)
# 678 - 🏢 'Ramesh J.' Company: NA (10K+ LinkedIn Family Connections | Talent Spotter | Team Builder | Tech Savvy | Compensation and Benefits specialist)
# 682 - 🏢 'Rodrigo Gutierrez' Company: NA (In the beginning was the word, but also physics. Human-Voice-Computer-Interaction.)
# 686 - 🏢 'Robert D'Elena' Company: NA (Linguist, Researcher, TPM)
# 687 - 🏢 'Roberta Evola' Company: NA (Project manager)
# 688 - 🏢 'Ravi K.' Company: NA (Data Engineering | Data Management & Integration Strategy | Product Management)
# 690 - 🏢 'Rohin Khanna' Company: NA (Product | Data & AI | Technology)
# 693 - 🏢 'Roman Cianci' Company: NA (Junior-Entrepreneur | Etudiant)
# 694 - 🏢 'Rome Thorndike' Company: NA (Building Something)
# 695 - 🏢 'Shreyas Sundaresh' Company: NA (Harnessing Data, Insights & AI to Solve High Value Use Cases || Delivering Hyper Growth & Strategic Transformation)
# 696 - 🏢 'Shruthi M S' Company: NA (Project Manager Data Analytics Data Visualisation)
# 697 - 🏢 'Awais Shah' Company: NA (Data Engineer | Data Scientist | ML Engineer)
# 698 - 🏢 'Ayesha Khurshid' Company: NA (BS(Artificial Intelligence) || DUET'26 || UI designer || Python || HTML || Css || C)
# 701 - 🏢 'Samanth Koduru' Company: Northeastern University (Actively looking for Full Time opportunities | Available from Jan 2024 | Generative AI | ML Ops | LLM Ops | NLP enthusiast | Data Engineering | Graduate student @ Northeastern University)
# 702 - 🏢 'Ronald Scherpenisse' Company: NA (Advisor & Analyst. GPTtrainer. Gig Mindset. Metaverse Tourguide. Podcast & Livestream producer. Host & moderator.)
# 703 - 🏢 'SUNNY BHAVEEN CHANDRA' Company: NA (Data Scientist | Software Engineer)
# 704 - 🏢 'Saad Hasan' Company: NA (Design, Development and Testing of Prototypes of Software Automation Tools using ML, Design Patterns and NLP)
# 705 - 🏢 'Beau Walker' Company: NA (CTO & Chief Data Scientist. Inventor. Dad.)
# 706 - 🏢 'Bedir Yılmaz' Company: NA (Machine Learning Engineer)
# 707 - 🏢 'Bekimpilo Ndlovu' Company: NA (AI (Responsible AI & AI Ethics) | AI Risk Management | NLP, LLMs | Data | Product management)
# 708 - 🏢 'Ben Thomas' Company: NA (Data Science and Engineering)
# 711 - 🏢 'Benjamin GIRAUD' Company: l'IUT Paris Rives de Seine (Étudiant en BUT techniques de commercialisation à l'IUT Paris Rives de Seine)
# 715 - 🏢 'Ankur Garg' Company: NA (Blockchain Consultant)
# 716 - 🏢 'Anne Turner' Company: NA (Biomedical Engineering Master’s graduate)
# 718 - 🏢 'Andres Gutierrez' Company: NA (Deputy Manager of Financial and Corporate Risks)
# 719 - 🏢 'Andrew Delany' Company: NA (Growth advisor to forward-thinking SMBs with product-future fit and their heart in the right place.)
# 721 - 🏢 'Satyan Prakash' Company: NA (Client Delivery Executive (Director))
# 724 - 🏢 'Sushanta Das' Company: NA (I like Training Neural Network)
# 726 - 🏢 'Svetlana Krasikova' Company: EDC Paris Business School (a Master's student at EDC Paris Business School (Innovation and Entrepreneurship))
# 728 - 🏢 'Sydney Lewis' Company: NA (Data Science)
# 731 - 🏢 'Shahrukh Shah' Company: NA (Full-Stack Software Developer | ML Engineer | Blockchain | AI Researcher)
# 738 - 🏢 'Shayan Safavi, PhD, PE' Company: NA (Data Science Manager | ML/AI Operations | Generative AI)
# 742 - 🏢 'Shreejan Shrestha' Company: NA (Machine Learning Engineer)
# 743 - 🏢 'Sebastien Le Calvez' Company: NA (Cloud Dev Sales & Customer Success leader)
# 744 - 🏢 'Serge Junior EKO' Company: NA (Apprentie opérateur en informatique (CFC))
# 745 - 🏢 'Siddharth Jindal' Company: NA (Technology Journalist)
# 746 - 🏢 'Simeon Ivaylov Petrov' Company: NA (Founder and Team Leader)
# 749 - 🏢 'Sina Ghorbani' Company: NA (CV | Medical image analysis |)
# 750 - 🏢 'Sineth Sankalpa' Company: NA (Artificial Intelligent Software Developer | Innovator | Teacher | Freelancer | Undergraduate)
# 751 - 🏢 'Shamal De Silva' Company: NA (Machine learning engineer)
# 753 - 🏢 'Vaidheesh V.' Company: NA (ML | Data Science | AI)
# 758 - 🏢 'Ana A.' Company: NA (Senior AML/KYC & Transfert Officer | FinCrime Analyst (Financial Investigation Unit))
# 762 - 🏢 'Son Truong Nguyen' Company: NA (Seeking Entry-Level Machine Learning Engineer, Data Scientist roles)
# 763 - 🏢 'Sophie Masson' Company: NA (Driving Digital Transformation | Change Management | Leadership and operational excellence | human focused)
# 765 - 🏢 'Uderson Fermino' Company: NA (CTO | CISO | Manager Architecture, Cybersecurity and Data Platform | AI, Blockchain, Crypto)
# 770 - 🏢 'Srikanth Kanukollu' Company: NA (Productivity Tech Operations)
# 771 - 🏢 'Srikanth Namuduri' Company: NA (Data Products | Analytics Engineering | Data Science | IoT | Systems Engineering)
# 774 - 🏢 'Stefan Lipp' Company: NA (create innovative investment solutions with automation and artificial intelligence)
# 780 - 🏢 'Steven Pais' Company: NA (Enterprise AI/ML Leader | Trusted Advisor | Monetizing data into profits | Business Strategy | Business Scientist | MLOps | GenAI)
# 781 - 🏢 'Sudhanshu Kanwar' Company: Goldman Sachs (Global Banking & Markets Strategist Investment Bank | Ex Goldman Sachs | Charter holder - CQF | FRM | CFA | LinkedIn Top Voice | Mentor & Educator | Board Member - Harvard Business Review)
# 782 - 🏢 'Sudhir A.' Company: NA (Solution Architect | Project Manager | PMP®| PRINCE2 Agile®| COBIT 5®)
# 783 - 🏢 'Suleyman Artun' Company: NA (Software Engineer (mid-level))
# 788 - 🏢 'Yabin Dong, PhD' Company: NA (Senior Algorithm Engineer | UMich alumnus)
# 792 - 🏢 'Aiman Manzoor Malik.' Company: NA (Data Analyst| AI| Machine Learning| Statistics| Python| SQL.)
# 793 - 🏢 'Yasmine R.' Company: NA (Supporting Organizations with Procurement & Finance Digital Transformation | Source-to-Pay | Procure-to-Pay Technology & Process | Ivalua expert)
# 795 - 🏢 'Yat Yan Ng' Company: NA (Assistant Project Manager)
# 798 - 🏢 'Aadil Feroze - PMP®' Company: NA (Cloud Engineer | B.E. Mechatronics | CCNA | AWS×4 | OCI×3 | Azure×1)
# 799 - 🏢 'Yousuf Q.' Company: NA (IOT engineer, software developer)
# 804 - 🏢 'Vishnukant P.' Company: NA (Team Lead Product Analytics (Analytics and Intelligence))
# 813 - 🏢 'Thomas Orimolade' Company: NA (Senior Business Operation Manager)
# 815 - 🏢 'Wayne Moodaley' Company: NA (Academic | Oxford MBA | Chartered Accountant | I simplify complex accounting and finance concepts.)
# 816 - 🏢 'Wendy Beaunom' Company: NA (Senior Policy Advisor)
# 817 - 🏢 'Vaishakh V' Company: NA (Machine Learning | AI & Deep Learning | Liverpool John Moores University - UK, M.S | IIIT-B, PG Diploma, Data Science)
# 824 - 🏢 'TBD Luis Herrera' Company: NA (The problem with computers is all they can do is provide answers (Picasso))
# 828 - 🏢 'Vikrant Deshpande' Company: Deloitte (Data Science | Machine Learning | Data Engineering | Statistics | Research | Graduate Program Ambassador | Ex-Deloitte)
# 830 - 🏢 'Vinoth Deva Kumar' Company: NA (Senior Business Analyst/Product Owner)
# 832 - 🏢 'Vishal Kumar' Company: Scale (UI Architect | Web Applications at Scale | Javascript | React | Angular | Node)
# 833 - 🏢 'Andrea Francesca Bellia' Company: NA (Advisor | MSc Biology & Project Management | Biologist | Ecologist)
# 840 - 🏢 'Amit Asthana' Company: NA (Operational Excellence | 3x Salesforce.com Certified | Triple Star Trailhead Ranger)
# 843 - 🏢 'Alan ENTEM' Company: NA (Ingénieur IA)
# 845 - 🏢 'Anastasiia S.' Company: NA (AI Enthusiast | CS Associate Prof. | HR & Operation Leader | Posting & learning about AI)
# 45 - 🧑‍💼 'Jörg Winterhoff' ICP: DataConsummer (Enabling business leaders in established SMEs to demystify AI, uncover valuable AI potentials and co-create meaningful AI solutions)
# 45 - 🏢 'Jörg Winterhoff' Company: NA (Enabling business leaders in established SMEs to demystify AI, uncover valuable AI potentials and co-create meaningful AI solutions)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3789         try:
# -> 3790             return self._engine.get_loc(casted_key)
#    3791         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'LINKEDINBIO'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-7c75f214a997> in <module>
#     147     return df.reset_index(drop=True)
#     148
# --> 149 df_leads_new = update_contacts_info(
#     150     df_profiles,
#     151     df_leads,
#
# <ipython-input-9-7c75f214a997> in update_contacts_info(df_init, df_leads, df_contacts, input_dir)
#     132         if crm_contact == "TBD":
#     133             for x in [profile_id, public_id]:
# --> 134                 tmp_df = df_contacts[df_contacts["LINKEDINBIO"].astype(str).str.contains(x)].reset_index(drop=True)
#     135                 if len(tmp_df) > 0:
#     136                     break
#
# ~/.local/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3891             if self.columns.nlevels > 1:
#    3892                 return self._getitem_multilevel(key)
# -> 3893             indexer = self.columns.get_loc(key)
#    3894             if is_integer(indexer):
#    3895                 indexer = [indexer]
#
# ~/.local/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3795             ):
#    3796                 raise InvalidIndexError(key)
# -> 3797             raise KeyError(key) from err
#    3798         except TypeError:
#    3799             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'LINKEDINBIO'

# %%
# def get_linkedin_url(company):
#     # Init linkedinbio
#     linkedinbio = "UNKNOWN"

#     # Create query
#     query = f"{company.replace(' ', '+')}+LinkedIn+company"
#     print("Google query: ", query)

#     # Search in Google
#     for i in search(query, tld="com", num=10, stop=10, pause=2):
#         pattern = "https:\/\/.+.linkedin.com\/company\/.([^?])+"
#         result = re.search(pattern, i)

#         # Return value if result is not None
#         if result != None:
#             linkedinbio = result.group(0).replace(" ", "")
#             time.sleep(2)
#             return linkedinbio
#     return linkedinbio

# def update_ref_company(
#     df_init,
#     df_contact,
#     ref_company,
#     input_dir
# ):
#     # Init
#     df = df_init.copy()
            
#     # Get companies from direct interactions
#     df_company_d = df_init.copy()
#     df_company_d = df_company_d[df_company_d["PROFILE_URL"].str.contains("https://www.linkedin.com/company/.+")]
#     to_keep = [
#         "FULLNAME",
#         "PROFILE_URL",
#         "INTERACTION_SCORE"
#     ]
#     to_rename = {
#         "FULLNAME": "COMPANY_NAME",
#         "PROFILE_URL": "LINKEDIN_URL",
#         "INTERACTION_SCORE": "DIRECT_INTERACTIONS"
#     }
#     df_company_d = df_company_d[to_keep].rename(columns=to_rename)
    
#     # Get companies from indirect interactions
#     df_company_i = df_contact.copy()
#     to_group = [
#         "COMPANY",
#     ]
#     to_agg = {
#         "INTERACTION_SCORE": "sum"
#     }
#     to_rename = {
#         "COMPANY": "COMPANY_NAME",
#         "INTERACTION_SCORE": "INDIRECT_INTERACTIONS"
#     }
#     df_company_i = df_company_i.groupby(to_group, as_index=False).agg(to_agg).rename(columns=to_rename)
    
#     # Concat
#     fillna = {
#         "LINKEDIN_URL": "TBD",
#         "DIRECT_INTERACTIONS": 0,
#         "INDIRECT_INTERACTIONS": 0
#     }
#     df_company = pd.concat([ref_company, df_company_d, df_company_i]).drop_duplicates("COMPANY_NAME").fillna(fillna)
#     df_company["INTERACTION_SCORE"] = df_company["DIRECT_INTERACTIONS"] * 5 + df_company["INDIRECT_INTERACTIONS"]
#     df_company = df_company.sort_values(by=["INTERACTION_SCORE"], ascending=[False])
#     df_company = df_company[df_company["COMPANY_NAME"] != "TBD"].reset_index(drop=True)
#     for row in df_company.itertuples():
#         index = row.Index
#         company_id = row.COMPANY_ID
#         company_name = row.COMPANY_NAME
#         linkedin_url = row.LINKEDIN_URL
#         interaction_score = row.INTERACTION_SCORE
#         if linkedin_url == "TBD":
#             print(f"{index} - Find LinkedIn URL for '{company_name}'")
#             linkedin_url = get_linkedin_url(company_name)
#             print("LinkedIn URL:", linkedin_url)
#             df_company.loc[index, "LINKEDIN_URL"] = linkedin_url
#             pdump(input_dir, df_company, "companies")
            
#         if "company" in linkedin_url and interaction_score >= 3 and str(company_id) == "None":
#             print(f"{index} - Update LinkedIn data '{company_name}':", linkedin_url, f'({int(interaction_score)})')
#             tmp_df = linkedin.connect(li_at, JSESSIONID).company.get_info(linkedin_url)
#             if len(tmp_df) > 0:
#                 company_name = tmp_df.loc[0, "COMPANY_NAME"].replace(" ", "_").lower()
#                 pdump(input_dir, tmp_df, f"{company_name}_linkedin_company")
#                 df_company.loc[index, "COMPANY_ID"] = tmp_df.loc[0, "COMPANY_ID"]
#                 df_company.loc[index, "COMPANY_NAME"] = tmp_df.loc[0, "COMPANY_NAME"]
#                 df_company.loc[index, "LINKEDIN_URL"] = tmp_df.loc[0, "COMPANY_URL"]
#                 df_company.loc[index, "INDUSTRY"] = tmp_df.loc[0, "INDUSTRY"]
#                 df_company.loc[index, "STAFF_COUNT"] = tmp_df.loc[0, "STAFF_COUNT"]
#                 df_company.loc[index, "STAFF_RANGE"] = tmp_df.loc[0, "STAFF_RANGE"]
#                 df_company.loc[index, "FOLLOWER_COUNT"] = tmp_df.loc[0, "FOLLOWER_COUNT"]
#                 df_company.loc[index, "COUNTRY"] = tmp_df.loc[0, "COUNTRY"]
#                 df_company.loc[index, "CITY"] = tmp_df.loc[0, "CITY"]
#                 df_company.loc[index, "WEBSITE"] = tmp_df.loc[0, "WEBSITE"]
#                 df_company.loc[index, "TAGLINE"] = tmp_df.loc[0, "TAGLINE"]
#                 df_company.loc[index, "DESCRIPTION"] = tmp_df.loc[0, "DESCRIPTION"]
#     return df_company.reset_index(drop=True)

# df_company = update_ref_company(
#     df_profiles,
#     df_contact,
#     ref_company,
#     input_dir
# )
# print("Companies:", len(df_company))
# df_company.head()

# %% [markdown]
# ## Output

# %% [markdown]
# ### Send "Leads" to spreadsheet

# %%
gsheet.connect(spreadsheet_url).send(data=df, sheet_name=ref_leads_name, append=False)

# %% [markdown]
# ### Send "Companies" to spreadsheet

# %%
gsheet.connect(spreadsheet_url).send(data=df_company, sheet_name=ref_company_name, append=False)
